# %%
# Various torch packages
import torch
import torch.nn as nn
import torch.nn.functional as F

# torchvision
from torchvision import datasets, transforms

# ------------------------
# get up one directory 
import sys, os
sys.path.append(os.path.abspath('../'))
# ------------------------

# custom packages
import matplotlib.pyplot as plt
import models.aux_funs as maf
import optimizers as op
import regularizers as reg
import train
import math
import utils.configuration as cf
import utils.datasets as ud
from models.mnist_conv import mnist_conv

# %%
datasets.FashionMNIST('./', train=True, download=True, transform=transforms.ToTensor())
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: ./
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %% [markdown]
# # Fix the random seed

# %%
random_seed = 0
cf.seed_torch(random_seed)

# %% [markdown]
# # Configure the experiment (current best)

# %%
conf_args = {#
    # data specification
    'data_file':"../../Data",'train_split':0.95, 'data_set':"Fashion-MNIST", 'download':True,
    # cuda
    'use_cuda':True, 'num_workers':4, 'cuda_device':0, 'pin_memory':True,
    #
    'epochs':100,
    # optimizer
    'delta': 1.0, 'lr':0.001, 'lamda_0':0.37, 'lamda_1':0.32, 'optim':"AdaBreg", 'row_group':True,
    'reg':reg.reg_l1_l2, 'beta':0.0,
    'conv_group':True,
    # initialization
    'sparse_init':0.01, 'r':[1,1,1],
    # misc
    'random_seed':random_seed, 'eval_acc':True,
}

conf = cf.Conf(**conf_args)

# %%
conf_args = {#
    # data specification
    'data_file':"../../Data",'train_split':0.95, 'data_set':"Fashion-MNIST", 'download':True,
    # cuda
    'use_cuda':True, 'num_workers':4, 'cuda_device':0, 'pin_memory':True, 'train_split':0.95,
    #
    'epochs':100,
    # optimizer
    'delta':1.0, 'lr':0.07, 'lamda_0':.4, 'lamda_1':.4, 'optim':"LinBreg", 'conv_group':True,
    'beta':0.0,
    # initialization
    'sparse_init':0.01, 'r':[10.,10.,10.],
    # misc
    'random_seed':random_seed, 'eval_acc':True,
}

conf = cf.Conf(**conf_args)

# %% [markdown]
# # Initiate the model

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    

model = mnist_conv(**model_kwargs)
best_model = train.best_model(mnist_conv(**model_kwargs).to(conf.device))

# %% [markdown]
# # Weight initialization

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    
def init_weights(conf, model):
    # sparsify
    maf.sparse_bias_uniform_(model, 0,conf.r[0])
    maf.sparse_bias_uniform_(model, 0,conf.r[0], ltype=torch.nn.Conv2d)
    maf.sparse_weight_normal_(model, conf.r[1])
    maf.sparse_weight_normal_(model, conf.r[2], ltype=torch.nn.Conv2d)
    #
    maf.sparsify_(model, conf.sparse_init, ltype = nn.Conv2d, conv_group=conf.conv_group)
    maf.sparsify_(model, conf.sparse_init, ltype = nn.Linear)
    model = model.to(conf.device)    
    return model

model = init_weights(conf,model)

# %% [markdown]
# # Optimizer

# %%
def init_opt(conf, model):
    # -----------------------------------------------------------------------------------
    # Get access to different model parameters
    # -----------------------------------------------------------------------------------
    weights_conv = maf.get_weights_conv(model)
    weights_linear = maf.get_weights_linear(model)
    biases = maf.get_bias(model)
    
    # -----------------------------------------------------------------------------------
    # Initialize optimizer
    # -----------------------------------------------------------------------------------
    if conf.conv_group:
        reg2 = reg.reg_l1_l2_conv(lamda=conf.lamda_0)
    else:
        reg2 = reg.reg_l1(lamda=conf.lamda_0)
    
    if conf.optim == "SGD":
        opt = torch.optim.SGD(model.parameters(), lr=conf.lr, momentum=conf.beta)
    elif conf.optim == "LinBreg":
        opt = op.LinBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])
    elif conf.optim == "ProxSGD":
        opt = op.ProxSGD([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])            
    elif conf.optim == "AdaBreg":
        opt = op.AdaBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2,'delta':conf.delta},
                           {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1),'delta':conf.delta},
                           {'params': biases, 'lr': conf.lr}])
    elif conf.optim == "L1SGD":
        def weight_reg(model):
            reg1 =  reg.reg_l1(lamda=conf.lamda_1)
        
            loss1 = reg1(model.layers2[0].weight) + reg1(model.layers2[2].weight)
            loss2 = reg2(model.layers1[0].weight) + reg2(model.layers1[3].weight)
            return loss1 + loss2
        
        conf.weight_reg = weight_reg
        
        opt = torch.optim.SGD(model.parameters(), lr=lr, momentum=beta)
    else:
        raise ValueError("Unknown Optimizer specified")

    # learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, factor=0.5, patience=5,threshold=0.01)
    
    return opt, scheduler

# %% [markdown]
# # Dataset

# %%
train_loader, valid_loader, test_loader = ud.get_data_set(conf)

# %% [markdown]
# # History and Runs

# %%
# Initialize history
tracked = ['loss', 'node_sparse']
train_hist = {}
val_hist = {}

# %% [markdown]
# # Training

# %%
# -----------------------------------------------------------------------------------
# Reinit weigts and the corresponding optimizer
# -----------------------------------------------------------------------------------
model = init_weights(conf, model)
opt, scheduler = init_opt(conf, model)

# -----------------------------------------------------------------------------------
# train the model
# -----------------------------------------------------------------------------------
for epoch in range(conf.epochs):
    print(25*"<>")
    print(50*"|")
    print(25*"<>")
    print('Epoch:', epoch)

    # ------------------------------------------------------------------------
    # train step, log the accuracy and loss
    # ------------------------------------------------------------------------
    train_data = train.train_step(conf, model, opt, train_loader)

    # update history
    for key in tracked:
        if key in train_data:
            var_list = train_hist.setdefault(key, [])
            var_list.append(train_data[key])           

    # ------------------------------------------------------------------------
    # validation step
    val_data = train.validation_step(conf, model, opt, valid_loader)

    # update validation history
    for key in tracked:
        if key in val_data:
            var = val_data[key]
            if isinstance(var, list):
                for i, var_loc in enumerate(var):
                    key_loc = key+"_" + str(i)
                    var_list = val_hist.setdefault(key_loc, [])
                    val_hist[key_loc].append(var_loc)
            else:
                var_list = val_hist.setdefault(key, [])
                var_list.append(var)   


    scheduler.step(train_data['loss'])
    print("Learning rate:",opt.param_groups[0]['lr'])
    best_model(train_data['acc'], val_data['acc'], model=model)
# Out:
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 0
# --------------------------------------------------
# Train Accuracy: 0.2285964912280702
# Train Loss: 127.31308233737946
# --------------------------------------------------
# Validation Accuracy: 0.353
# Non-zero kernels: 0.01201923076923077
# Linear sparsity: 0.010691187137330754
# Overall sparsity: 0.011275555104251286
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [179.37945938110352, 193.9429626464844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 1
# --------------------------------------------------
# Train Accuracy: 0.5368245614035088
# Train Loss: 74.50646954774857
# --------------------------------------------------
# Validation Accuracy: 0.6033333333333334
# Non-zero kernels: 0.013701923076923077
# Linear sparsity: 0.011220079787234043
# Overall sparsity: 0.012312144597887896
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [181.11006927490234, 196.7309356689453, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 2
# --------------------------------------------------
# Train Accuracy: 0.6289473684210526
# Train Loss: 60.895529091358185
# --------------------------------------------------
# Validation Accuracy: 0.665
# Non-zero kernels: 0.014423076923076924
# Linear sparsity: 0.011454303675048357
# Overall sparsity: 0.01276062821554292
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [182.24549865722656, 198.1744499206543, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 3
# --------------------------------------------------
# Train Accuracy: 0.6860701754385965
# Train Loss: 48.71879601478577
# --------------------------------------------------
# Validation Accuracy: 0.6926666666666667
# Non-zero kernels: 0.014663461538461538
# Linear sparsity: 0.011514748549323018
# Overall sparsity: 0.012900250473869482
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [182.44781494140625, 199.10785369873048, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 4
# --------------------------------------------------
# Train Accuracy: 0.7041754385964912
# Train Loss: 44.81276226043701
# --------------------------------------------------
# Validation Accuracy: 0.6986666666666667
# Non-zero kernels: 0.014903846153846155
# Linear sparsity: 0.011560082205029014
# Overall sparsity: 0.013031410777145952
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [182.57801818847656, 199.67290802001955, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 5
# --------------------------------------------------
# Train Accuracy: 0.7146666666666667
# Train Loss: 43.27036064863205
# --------------------------------------------------
# Validation Accuracy: 0.7066666666666667
# Non-zero kernels: 0.01514423076923077
# Linear sparsity: 0.011544970986460347
# Overall sparsity: 0.013128723260222042
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [182.81034088134766, 200.21862869262696, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 6
# --------------------------------------------------
# Train Accuracy: 0.7215263157894737
# Train Loss: 41.861987709999084
# --------------------------------------------------
# Validation Accuracy: 0.7166666666666667
# Non-zero kernels: 0.01514423076923077
# Linear sparsity: 0.011620527079303675
# Overall sparsity: 0.013171033035472516
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [183.02124404907227, 200.6747055053711, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 7
# --------------------------------------------------
# Train Accuracy: 0.7248771929824561
# Train Loss: 41.81055837869644
# --------------------------------------------------
# Validation Accuracy: 0.7143333333333334
# Non-zero kernels: 0.015384615384615385
# Linear sparsity: 0.011696083172147003
# Overall sparsity: 0.013319117248849174
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [183.28881454467773, 201.08601989746094, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 8
# --------------------------------------------------
# Train Accuracy: 0.7287543859649123
# Train Loss: 40.59888142347336
# --------------------------------------------------
# Validation Accuracy: 0.7226666666666667
# Non-zero kernels: 0.01610576923076923
# Linear sparsity: 0.011809417311411993
# Overall sparsity: 0.013699905226103438
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [183.71877670288086, 201.62256164550783, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 9
# --------------------------------------------------
# Train Accuracy: 0.7350350877192983
# Train Loss: 39.52520453929901
# --------------------------------------------------
# Validation Accuracy: 0.721
# Non-zero kernels: 0.01610576923076923
# Linear sparsity: 0.011884973404255319
# Overall sparsity: 0.013742215001353912
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [184.07960510253906, 202.17566070556643, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 10
# --------------------------------------------------
# Train Accuracy: 0.7390350877192983
# Train Loss: 39.20863252878189
# --------------------------------------------------
# Validation Accuracy: 0.7376666666666667
# Non-zero kernels: 0.01610576923076923
# Linear sparsity: 0.011983196324951643
# Overall sparsity: 0.013797217709179528
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [184.37955474853516, 202.65892944335937, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 11
# --------------------------------------------------
# Train Accuracy: 0.7394912280701754
# Train Loss: 39.192573606967926
# --------------------------------------------------
# Validation Accuracy: 0.7346666666666667
# Non-zero kernels: 0.01610576923076923
# Linear sparsity: 0.012088974854932301
# Overall sparsity: 0.013856451394530192
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [184.60345077514648, 203.23726196289064, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 12
# --------------------------------------------------
# Train Accuracy: 0.7457368421052631
# Train Loss: 38.114003121852875
# --------------------------------------------------
# Validation Accuracy: 0.738
# Non-zero kernels: 0.01610576923076923
# Linear sparsity: 0.012179642166344293
# Overall sparsity: 0.01390722312483076
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [184.83843231201172, 203.800732421875, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 13
# --------------------------------------------------
# Train Accuracy: 0.749561403508772
# Train Loss: 37.49479782581329
# --------------------------------------------------
# Validation Accuracy: 0.7416666666666667
# Non-zero kernels: 0.01610576923076923
# Linear sparsity: 0.012345865570599614
# Overall sparsity: 0.014000304630381804
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [184.97300338745117, 204.41512603759767, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 14
# --------------------------------------------------
# Train Accuracy: 0.7572982456140351
# Train Loss: 36.62365019321442
# --------------------------------------------------
# Validation Accuracy: 0.7463333333333333
# Non-zero kernels: 0.016346153846153847
# Linear sparsity: 0.012406310444874275
# Overall sparsity: 0.014139926888708368
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [185.21305084228516, 205.01350708007814, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 15
# --------------------------------------------------
# Train Accuracy: 0.7575614035087719
# Train Loss: 36.31100797653198
# --------------------------------------------------
# Validation Accuracy: 0.7423333333333333
# Non-zero kernels: 0.016346153846153847
# Linear sparsity: 0.012519644584139265
# Overall sparsity: 0.014203391551584078
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [185.42066955566406, 205.61644592285157, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 16
# --------------------------------------------------
# Train Accuracy: 0.761438596491228
# Train Loss: 35.61471331119537
# --------------------------------------------------
# Validation Accuracy: 0.754
# Non-zero kernels: 0.016346153846153847
# Linear sparsity: 0.012564978239845261
# Overall sparsity: 0.014228777416734362
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [185.55109786987305, 206.1115692138672, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 17
# --------------------------------------------------
# Train Accuracy: 0.764719298245614
# Train Loss: 35.064642786979675
# --------------------------------------------------
# Validation Accuracy: 0.752
# Non-zero kernels: 0.01658653846153846
# Linear sparsity: 0.012648089941972921
# Overall sparsity: 0.014381092607636068
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [185.74520874023438, 206.58265838623046, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 18
# --------------------------------------------------
# Train Accuracy: 0.7683333333333333
# Train Loss: 34.60066771507263
# --------------------------------------------------
# Validation Accuracy: 0.7553333333333333
# Non-zero kernels: 0.01658653846153846
# Linear sparsity: 0.012738757253384914
# Overall sparsity: 0.014431864337936636
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [185.94868850708008, 207.02142486572265, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 19
# --------------------------------------------------
# Train Accuracy: 0.7706666666666667
# Train Loss: 34.32890033721924
# --------------------------------------------------
# Validation Accuracy: 0.7626666666666667
# Non-zero kernels: 0.01658653846153846
# Linear sparsity: 0.01278409090909091
# Overall sparsity: 0.014457250203086922
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [186.09796142578125, 207.44233703613284, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 20
# --------------------------------------------------
# Train Accuracy: 0.7738771929824562
# Train Loss: 34.068898260593414
# --------------------------------------------------
# Validation Accuracy: 0.7463333333333333
# Non-zero kernels: 0.016826923076923076
# Linear sparsity: 0.012889869439071567
# Overall sparsity: 0.01462225832656377
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [186.32245254516602, 207.90768127441407, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 21
# --------------------------------------------------
# Train Accuracy: 0.7777017543859649
# Train Loss: 33.5085169672966
# --------------------------------------------------
# Validation Accuracy: 0.7606666666666667
# Non-zero kernels: 0.01706730769230769
# Linear sparsity: 0.01295786992263056
# Overall sparsity: 0.01476611156241538
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [186.55467224121094, 208.28836975097659, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 22
# --------------------------------------------------
# Train Accuracy: 0.7773157894736842
# Train Loss: 33.420004308223724
# --------------------------------------------------
# Validation Accuracy: 0.7603333333333333
# Non-zero kernels: 0.01730769230769231
# Linear sparsity: 0.013086315280464217
# Overall sparsity: 0.01494381261846737
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [186.74869537353516, 208.71018524169924, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 23
# --------------------------------------------------
# Train Accuracy: 0.781140350877193
# Train Loss: 33.04214662313461
# --------------------------------------------------
# Validation Accuracy: 0.7693333333333333
# Non-zero kernels: 0.01706730769230769
# Linear sparsity: 0.01315431576402321
# Overall sparsity: 0.014876116978066612
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [187.01943588256836, 209.13663635253906, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 24
# --------------------------------------------------
# Train Accuracy: 0.783
# Train Loss: 32.7951038479805
# --------------------------------------------------
# Validation Accuracy: 0.7676666666666667
# Non-zero kernels: 0.01730769230769231
# Linear sparsity: 0.013184538201160542
# Overall sparsity: 0.014998815326292986
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [187.1875877380371, 209.57269592285155, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 25
# --------------------------------------------------
# Train Accuracy: 0.7880877192982456
# Train Loss: 32.11425960063934
# --------------------------------------------------
# Validation Accuracy: 0.766
# Non-zero kernels: 0.01706730769230769
# Linear sparsity: 0.013229871856866538
# Overall sparsity: 0.014918426753317086
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [187.29226303100586, 209.9704315185547, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 26
# --------------------------------------------------
# Train Accuracy: 0.7841929824561403
# Train Loss: 32.535143077373505
# --------------------------------------------------
# Validation Accuracy: 0.7733333333333333
# Non-zero kernels: 0.017548076923076923
# Linear sparsity: 0.013305427949709864
# Overall sparsity: 0.01517228540481993
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [187.49591064453125, 210.3448654174805, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 27
# --------------------------------------------------
# Train Accuracy: 0.788140350877193
# Train Loss: 31.955783039331436
# --------------------------------------------------
# Validation Accuracy: 0.7726666666666666
# Non-zero kernels: 0.017548076923076923
# Linear sparsity: 0.013380984042553192
# Overall sparsity: 0.015214595180070404
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [187.71957397460938, 210.73069458007814, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 28
# --------------------------------------------------
# Train Accuracy: 0.7952631578947369
# Train Loss: 31.314669638872147
# --------------------------------------------------
# Validation Accuracy: 0.7816666666666666
# Non-zero kernels: 0.018028846153846152
# Linear sparsity: 0.013448984526112186
# Overall sparsity: 0.0154642228540482
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [187.9358367919922, 211.1140289306641, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 29
# --------------------------------------------------
# Train Accuracy: 0.7906842105263158
# Train Loss: 31.55871257185936
# --------------------------------------------------
# Validation Accuracy: 0.781
# Non-zero kernels: 0.017788461538461538
# Linear sparsity: 0.013501873791102514
# Overall sparsity: 0.015388065258597346
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [188.02630233764648, 211.46381225585938, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 30
# --------------------------------------------------
# Train Accuracy: 0.7957017543859649
# Train Loss: 31.044344782829285
# --------------------------------------------------
# Validation Accuracy: 0.7893333333333333
# Non-zero kernels: 0.017788461538461538
# Linear sparsity: 0.013622763539651838
# Overall sparsity: 0.015455760898998104
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [188.2737808227539, 211.88637695312502, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 31
# --------------------------------------------------
# Train Accuracy: 0.7963333333333333
# Train Loss: 30.93899431824684
# --------------------------------------------------
# Validation Accuracy: 0.783
# Non-zero kernels: 0.017788461538461538
# Linear sparsity: 0.013698319632495164
# Overall sparsity: 0.015498070674248578
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [188.5181541442871, 212.27818908691407, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 32
# --------------------------------------------------
# Train Accuracy: 0.797140350877193
# Train Loss: 30.64779880642891
# --------------------------------------------------
# Validation Accuracy: 0.78
# Non-zero kernels: 0.017788461538461538
# Linear sparsity: 0.013736097678916828
# Overall sparsity: 0.015519225561873816
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [188.63349151611328, 212.60944213867188, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 33
# --------------------------------------------------
# Train Accuracy: 0.7991929824561403
# Train Loss: 30.488976150751114
# --------------------------------------------------
# Validation Accuracy: 0.789
# Non-zero kernels: 0.017788461538461538
# Linear sparsity: 0.013788986943907157
# Overall sparsity: 0.015548842404549148
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [188.79697036743164, 213.00237274169922, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 34
# --------------------------------------------------
# Train Accuracy: 0.8032105263157895
# Train Loss: 30.064069986343384
# --------------------------------------------------
# Validation Accuracy: 0.786
# Non-zero kernels: 0.017788461538461538
# Linear sparsity: 0.01379654255319149
# Overall sparsity: 0.015553073382074194
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [188.9983787536621, 213.3592544555664, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 35
# --------------------------------------------------
# Train Accuracy: 0.8047017543859649
# Train Loss: 29.91289234161377
# --------------------------------------------------
# Validation Accuracy: 0.7846666666666666
# Non-zero kernels: 0.017788461538461538
# Linear sparsity: 0.013834320599613153
# Overall sparsity: 0.015574228269699432
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [189.16588592529297, 213.6856414794922, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 36
# --------------------------------------------------
# Train Accuracy: 0.8043333333333333
# Train Loss: 29.801139444112778
# --------------------------------------------------
# Validation Accuracy: 0.7896666666666666
# Non-zero kernels: 0.018028846153846152
# Linear sparsity: 0.013887209864603482
# Overall sparsity: 0.015709619550500948
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [189.37829971313477, 214.04051513671877, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 37
# --------------------------------------------------
# Train Accuracy: 0.8061052631578948
# Train Loss: 29.630608290433884
# --------------------------------------------------
# Validation Accuracy: 0.7863333333333333
# Non-zero kernels: 0.018028846153846152
# Linear sparsity: 0.013917432301740812
# Overall sparsity: 0.015726543460601136
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [189.59621810913086, 214.3501907348633, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 38
# --------------------------------------------------
# Train Accuracy: 0.8080877192982456
# Train Loss: 29.302485525608063
# --------------------------------------------------
# Validation Accuracy: 0.7833333333333333
# Non-zero kernels: 0.018028846153846152
# Linear sparsity: 0.013985432785299807
# Overall sparsity: 0.015764622258326564
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [189.7262077331543, 214.6505828857422, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 39
# --------------------------------------------------
# Train Accuracy: 0.8077894736842105
# Train Loss: 29.327308863401413
# --------------------------------------------------
# Validation Accuracy: 0.8016666666666666
# Non-zero kernels: 0.018028846153846152
# Linear sparsity: 0.014060988878143133
# Overall sparsity: 0.015806932033577036
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [189.95412826538086, 214.9415435791016, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 40
# --------------------------------------------------
# Train Accuracy: 0.8090526315789474
# Train Loss: 29.163246244192123
# --------------------------------------------------
# Validation Accuracy: 0.7963333333333333
# Non-zero kernels: 0.018028846153846152
# Linear sparsity: 0.014128989361702128
# Overall sparsity: 0.015845010831302464
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [190.09704208374023, 215.22505950927734, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 41
# --------------------------------------------------
# Train Accuracy: 0.8107017543859649
# Train Loss: 28.9765987098217
# --------------------------------------------------
# Validation Accuracy: 0.7656666666666667
# Non-zero kernels: 0.01826923076923077
# Linear sparsity: 0.014174323017408124
# Overall sparsity: 0.015976171134578932
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [190.3091926574707, 215.5248519897461, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 42
# --------------------------------------------------
# Train Accuracy: 0.8124561403508772
# Train Loss: 28.88626852631569
# --------------------------------------------------
# Validation Accuracy: 0.7866666666666666
# Non-zero kernels: 0.01826923076923077
# Linear sparsity: 0.014242323500967118
# Overall sparsity: 0.01601424993230436
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [190.50983428955078, 215.8124038696289, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 43
# --------------------------------------------------
# Train Accuracy: 0.8117192982456141
# Train Loss: 28.804259330034256
# --------------------------------------------------
# Validation Accuracy: 0.7963333333333333
# Non-zero kernels: 0.01875
# Linear sparsity: 0.01433299081237911
# Overall sparsity: 0.016276570538857296
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [190.65132904052734, 216.05056762695312, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 44
# --------------------------------------------------
# Train Accuracy: 0.8139298245614035
# Train Loss: 28.361629366874695
# --------------------------------------------------
# Validation Accuracy: 0.8056666666666666
# Non-zero kernels: 0.018509615384615385
# Linear sparsity: 0.014378324468085107
# Overall sparsity: 0.016196181965881396
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [190.7979850769043, 216.35319824218752, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 45
# --------------------------------------------------
# Train Accuracy: 0.8139824561403509
# Train Loss: 28.40247005224228
# --------------------------------------------------
# Validation Accuracy: 0.8033333333333333
# Non-zero kernels: 0.01875
# Linear sparsity: 0.014484102998065764
# Overall sparsity: 0.016361190089358244
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [190.98322677612305, 216.6093505859375, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 46
# --------------------------------------------------
# Train Accuracy: 0.8165438596491228
# Train Loss: 28.198897153139114
# --------------------------------------------------
# Validation Accuracy: 0.7936666666666666
# Non-zero kernels: 0.01875
# Linear sparsity: 0.014567214700193424
# Overall sparsity: 0.016407730842133768
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [191.11040115356445, 216.8510543823242, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 47
# --------------------------------------------------
# Train Accuracy: 0.8161929824561404
# Train Loss: 28.077174335718155
# --------------------------------------------------
# Validation Accuracy: 0.798
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.014597437137330754
# Overall sparsity: 0.01653042919036014
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [191.36885452270508, 217.1294403076172, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 48
# --------------------------------------------------
# Train Accuracy: 0.8152631578947368
# Train Loss: 28.220439821481705
# --------------------------------------------------
# Validation Accuracy: 0.795
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.014657882011605415
# Overall sparsity: 0.01656427701056052
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [191.4853973388672, 217.40573120117188, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 49
# --------------------------------------------------
# Train Accuracy: 0.8190175438596491
# Train Loss: 28.100965470075607
# --------------------------------------------------
# Validation Accuracy: 0.798
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.014771216150870407
# Overall sparsity: 0.016627741673436232
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [191.64617919921875, 217.673095703125, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 50
# --------------------------------------------------
# Train Accuracy: 0.8194912280701755
# Train Loss: 27.74742090702057
# --------------------------------------------------
# Validation Accuracy: 0.8036666666666666
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.0148392166344294
# Overall sparsity: 0.016665820471161656
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [191.83538436889648, 217.98043060302737, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 51
# --------------------------------------------------
# Train Accuracy: 0.8189122807017544
# Train Loss: 27.753455191850662
# --------------------------------------------------
# Validation Accuracy: 0.799
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.01492232833655706
# Overall sparsity: 0.01671236122393718
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [191.94391632080078, 218.25914916992187, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 52
# --------------------------------------------------
# Train Accuracy: 0.8191929824561404
# Train Loss: 27.656609266996384
# --------------------------------------------------
# Validation Accuracy: 0.808
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.014967661992263057
# Overall sparsity: 0.016737747089087464
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [192.1427459716797, 218.60417785644532, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 53
# --------------------------------------------------
# Train Accuracy: 0.8227543859649122
# Train Loss: 27.316514372825623
# --------------------------------------------------
# Validation Accuracy: 0.8043333333333333
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.015028106866537718
# Overall sparsity: 0.01677159490928784
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [192.27021026611328, 218.85195312500002, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 54
# --------------------------------------------------
# Train Accuracy: 0.8230526315789474
# Train Loss: 27.384085834026337
# --------------------------------------------------
# Validation Accuracy: 0.8126666666666666
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.015073440522243714
# Overall sparsity: 0.016796980774438128
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [192.38362884521484, 219.15667419433595, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 55
# --------------------------------------------------
# Train Accuracy: 0.8201754385964912
# Train Loss: 27.52598398923874
# --------------------------------------------------
# Validation Accuracy: 0.8143333333333334
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.015133885396518375
# Overall sparsity: 0.016830828594638504
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [192.50263214111328, 219.39718627929688, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 56
# --------------------------------------------------
# Train Accuracy: 0.8236315789473684
# Train Loss: 27.09958639740944
# --------------------------------------------------
# Validation Accuracy: 0.8173333333333334
# Non-zero kernels: 0.019230769230769232
# Linear sparsity: 0.015156552224371374
# Overall sparsity: 0.016949295965339832
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [192.7010612487793, 219.6953063964844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 57
# --------------------------------------------------
# Train Accuracy: 0.8235614035087719
# Train Loss: 27.20714247226715
# --------------------------------------------------
# Validation Accuracy: 0.813
# Non-zero kernels: 0.018990384615384614
# Linear sparsity: 0.015194330270793036
# Overall sparsity: 0.016864676414838884
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [192.8195343017578, 219.90497131347655, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 58
# --------------------------------------------------
# Train Accuracy: 0.8248421052631579
# Train Loss: 27.000846028327942
# --------------------------------------------------
# Validation Accuracy: 0.8193333333333334
# Non-zero kernels: 0.019471153846153846
# Linear sparsity: 0.015254775145067699
# Overall sparsity: 0.017110073111291632
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [192.97534561157227, 220.20284729003907, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 59
# --------------------------------------------------
# Train Accuracy: 0.8273157894736842
# Train Loss: 26.70750841498375
# --------------------------------------------------
# Validation Accuracy: 0.8093333333333333
# Non-zero kernels: 0.019471153846153846
# Linear sparsity: 0.015405887330754353
# Overall sparsity: 0.01719469266179258
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [193.07345581054688, 220.4677978515625, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 60
# --------------------------------------------------
# Train Accuracy: 0.8252105263157895
# Train Loss: 26.848421961069107
# --------------------------------------------------
# Validation Accuracy: 0.805
# Non-zero kernels: 0.019230769230769232
# Linear sparsity: 0.015451220986460347
# Overall sparsity: 0.01711430408881668
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [193.24860382080078, 220.72575683593752, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 61
# --------------------------------------------------
# Train Accuracy: 0.828421052631579
# Train Loss: 26.482294470071793
# --------------------------------------------------
# Validation Accuracy: 0.8266666666666667
# Non-zero kernels: 0.019471153846153846
# Linear sparsity: 0.015488999032882011
# Overall sparsity: 0.0172412334145681
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [193.50198364257812, 221.0581085205078, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 62
# --------------------------------------------------
# Train Accuracy: 0.8243333333333334
# Train Loss: 27.034659892320633
# --------------------------------------------------
# Validation Accuracy: 0.8143333333333334
# Non-zero kernels: 0.019471153846153846
# Linear sparsity: 0.01551166586073501
# Overall sparsity: 0.017253926347143244
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [193.6325454711914, 221.29360351562502, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 63
# --------------------------------------------------
# Train Accuracy: 0.8280701754385965
# Train Loss: 26.47469189763069
# --------------------------------------------------
# Validation Accuracy: 0.8183333333333334
# Non-zero kernels: 0.019230769230769232
# Linear sparsity: 0.015617444390715668
# Overall sparsity: 0.017207385594367724
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [193.7211685180664, 221.62608337402347, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 64
# --------------------------------------------------
# Train Accuracy: 0.8278771929824561
# Train Loss: 26.46990367770195
# --------------------------------------------------
# Validation Accuracy: 0.8243333333333334
# Non-zero kernels: 0.019230769230769232
# Linear sparsity: 0.015647666827853
# Overall sparsity: 0.017224309504467912
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [193.83704376220703, 221.88838806152344, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 65
# --------------------------------------------------
# Train Accuracy: 0.8305087719298245
# Train Loss: 26.35945925116539
# --------------------------------------------------
# Validation Accuracy: 0.8043333333333333
# Non-zero kernels: 0.01971153846153846
# Linear sparsity: 0.015693000483558994
# Overall sparsity: 0.017461244245870564
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [194.02588653564453, 222.15557250976565, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 66
# --------------------------------------------------
# Train Accuracy: 0.8301754385964912
# Train Loss: 26.238861352205276
# --------------------------------------------------
# Validation Accuracy: 0.8196666666666667
# Non-zero kernels: 0.019471153846153846
# Linear sparsity: 0.015776112185686655
# Overall sparsity: 0.017402010560519904
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [194.0822639465332, 222.41135864257814, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 67
# --------------------------------------------------
# Train Accuracy: 0.8316315789473684
# Train Loss: 25.993033945560455
# --------------------------------------------------
# Validation Accuracy: 0.8103333333333333
# Non-zero kernels: 0.019471153846153846
# Linear sparsity: 0.015897001934235978
# Overall sparsity: 0.01746970620092066
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [194.250244140625, 222.74078369140625, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 68
# --------------------------------------------------
# Train Accuracy: 0.8313859649122807
# Train Loss: 26.109518736600876
# --------------------------------------------------
# Validation Accuracy: 0.8216666666666667
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.015912113152804643
# Overall sparsity: 0.017689717032223124
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [194.3955078125, 223.00035095214844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 69
# --------------------------------------------------
# Train Accuracy: 0.8308771929824561
# Train Loss: 25.951166540384293
# --------------------------------------------------
# Validation Accuracy: 0.829
# Non-zero kernels: 0.020192307692307693
# Linear sparsity: 0.015972558027079305
# Overall sparsity: 0.017829339290549688
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [194.54550170898438, 223.31120300292972, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 70
# --------------------------------------------------
# Train Accuracy: 0.8322631578947368
# Train Loss: 25.840852677822113
# --------------------------------------------------
# Validation Accuracy: 0.825
# Non-zero kernels: 0.020192307692307693
# Linear sparsity: 0.016002780464216635
# Overall sparsity: 0.01784626320064988
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [194.62433624267578, 223.58231506347659, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 71
# --------------------------------------------------
# Train Accuracy: 0.8334035087719298
# Train Loss: 25.632044166326523
# --------------------------------------------------
# Validation Accuracy: 0.8276666666666667
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.016025447292069634
# Overall sparsity: 0.017753181695098836
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [194.67698669433594, 223.79539794921877, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 72
# --------------------------------------------------
# Train Accuracy: 0.8330701754385965
# Train Loss: 25.811132550239563
# --------------------------------------------------
# Validation Accuracy: 0.8166666666666667
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.016078336557059963
# Overall sparsity: 0.017782798537774168
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [194.8705940246582, 224.11133728027346, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 73
# --------------------------------------------------
# Train Accuracy: 0.8350350877192982
# Train Loss: 25.596734672784805
# --------------------------------------------------
# Validation Accuracy: 0.804
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.01610100338491296
# Overall sparsity: 0.017795491470349308
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [194.9974479675293, 224.3567657470703, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 74
# --------------------------------------------------
# Train Accuracy: 0.8359473684210527
# Train Loss: 25.378452628850937
# --------------------------------------------------
# Validation Accuracy: 0.8096666666666666
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.016176559477756286
# Overall sparsity: 0.017837801245599784
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [195.0948257446289, 224.58721923828128, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 75
# --------------------------------------------------
# Train Accuracy: 0.8368771929824561
# Train Loss: 25.30116632580757
# --------------------------------------------------
# Validation Accuracy: 0.829
# Non-zero kernels: 0.020192307692307693
# Linear sparsity: 0.016176559477756286
# Overall sparsity: 0.017943575683725968
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [195.28689575195312, 224.84860229492188, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 76
# --------------------------------------------------
# Train Accuracy: 0.8348245614035088
# Train Loss: 25.568699151277542
# --------------------------------------------------
# Validation Accuracy: 0.8233333333333334
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.01623700435203095
# Overall sparsity: 0.017871649065800164
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [195.34334182739258, 225.11202087402344, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 77
# --------------------------------------------------
# Train Accuracy: 0.8347894736842105
# Train Loss: 25.385878443717957
# --------------------------------------------------
# Validation Accuracy: 0.8133333333333334
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.016305004835589942
# Overall sparsity: 0.017909727863525588
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [195.5320053100586, 225.37232360839846, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 78
# --------------------------------------------------
# Train Accuracy: 0.8369824561403508
# Train Loss: 25.304379403591156
# --------------------------------------------------
# Validation Accuracy: 0.832
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.01632767166344294
# Overall sparsity: 0.017922420796100732
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [195.66445541381836, 225.63277435302734, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 79
# --------------------------------------------------
# Train Accuracy: 0.8393859649122807
# Train Loss: 24.967384964227676
# --------------------------------------------------
# Validation Accuracy: 0.807
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.016425894584139265
# Overall sparsity: 0.017977423503926348
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [195.71499633789062, 225.8802703857422, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 80
# --------------------------------------------------
# Train Accuracy: 0.8398771929824561
# Train Loss: 25.043179541826248
# --------------------------------------------------
# Validation Accuracy: 0.824
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.016471228239845263
# Overall sparsity: 0.018002809369076632
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [195.8031997680664, 226.10022888183593, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 81
# --------------------------------------------------
# Train Accuracy: 0.837859649122807
# Train Loss: 24.910682767629623
# --------------------------------------------------
# Validation Accuracy: 0.8103333333333333
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.016516561895551257
# Overall sparsity: 0.018028195234226916
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [195.93515014648438, 226.38509216308594, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 82
# --------------------------------------------------
# Train Accuracy: 0.8396491228070175
# Train Loss: 24.900382578372955
# --------------------------------------------------
# Validation Accuracy: 0.823
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.01658456237911025
# Overall sparsity: 0.018066274031952344
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [196.1266860961914, 226.62032470703124, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 83
# --------------------------------------------------
# Train Accuracy: 0.8417368421052631
# Train Loss: 24.67446854710579
# --------------------------------------------------
# Validation Accuracy: 0.8193333333333334
# Non-zero kernels: 0.019951923076923075
# Linear sparsity: 0.01662989603481625
# Overall sparsity: 0.018091659897102628
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [196.27999877929688, 226.8691162109375, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 84
# --------------------------------------------------
# Train Accuracy: 0.8402631578947368
# Train Loss: 24.750728994607925
# --------------------------------------------------
# Validation Accuracy: 0.826
# Non-zero kernels: 0.020192307692307693
# Linear sparsity: 0.016735674564796906
# Overall sparsity: 0.018256668020579476
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [196.41909408569336, 227.1455993652344, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 85
# --------------------------------------------------
# Train Accuracy: 0.839859649122807
# Train Loss: 24.773370057344437
# --------------------------------------------------
# Validation Accuracy: 0.827
# Non-zero kernels: 0.020192307692307693
# Linear sparsity: 0.01677345261121857
# Overall sparsity: 0.018277822908204712
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [196.53014755249023, 227.43105926513675, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 86
# --------------------------------------------------
# Train Accuracy: 0.8406140350877193
# Train Loss: 24.688202619552612
# --------------------------------------------------
# Validation Accuracy: 0.8306666666666667
# Non-zero kernels: 0.020432692307692308
# Linear sparsity: 0.0168263418762089
# Overall sparsity: 0.018413214189006228
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [196.6653060913086, 227.7016784667969, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 87
# --------------------------------------------------
# Train Accuracy: 0.8416315789473684
# Train Loss: 24.55874103307724
# --------------------------------------------------
# Validation Accuracy: 0.8283333333333334
# Non-zero kernels: 0.020192307692307693
# Linear sparsity: 0.016864119922630563
# Overall sparsity: 0.01832859463850528
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [196.73136138916016, 227.92156829833988, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 88
# --------------------------------------------------
# Train Accuracy: 0.8421578947368421
# Train Loss: 24.521309286355972
# --------------------------------------------------
# Validation Accuracy: 0.8126666666666666
# Non-zero kernels: 0.020192307692307693
# Linear sparsity: 0.016871675531914893
# Overall sparsity: 0.018332825616030328
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [196.78103637695312, 228.12564086914062, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 89
# --------------------------------------------------
# Train Accuracy: 0.8427894736842105
# Train Loss: 24.321569830179214
# --------------------------------------------------
# Validation Accuracy: 0.8233333333333334
# Non-zero kernels: 0.020192307692307693
# Linear sparsity: 0.01695478723404255
# Overall sparsity: 0.018379366368805848
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [196.98157119750977, 228.3926727294922, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 90
# --------------------------------------------------
# Train Accuracy: 0.8400526315789474
# Train Loss: 24.724581718444824
# --------------------------------------------------
# Validation Accuracy: 0.836
# Non-zero kernels: 0.020673076923076922
# Linear sparsity: 0.01703034332688588
# Overall sparsity: 0.018633225020308692
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [197.11401748657227, 228.65385589599612, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 91
# --------------------------------------------------
# Train Accuracy: 0.8436140350877193
# Train Loss: 24.219138622283936
# --------------------------------------------------
# Validation Accuracy: 0.8246666666666667
# Non-zero kernels: 0.020673076923076922
# Linear sparsity: 0.01703034332688588
# Overall sparsity: 0.018633225020308692
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [197.22186660766602, 228.85229644775393, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 92
# --------------------------------------------------
# Train Accuracy: 0.8453684210526315
# Train Loss: 24.050269782543182
# --------------------------------------------------
# Validation Accuracy: 0.8366666666666667
# Non-zero kernels: 0.020913461538461537
# Linear sparsity: 0.017098343810444873
# Overall sparsity: 0.018777078256160304
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [197.34859085083008, 229.1258270263672, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 93
# --------------------------------------------------
# Train Accuracy: 0.843859649122807
# Train Loss: 24.244297116994858
# --------------------------------------------------
# Validation Accuracy: 0.83
# Non-zero kernels: 0.020673076923076922
# Linear sparsity: 0.01720412234042553
# Overall sparsity: 0.018730537503384784
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [197.42718887329102, 229.30489196777347, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 94
# --------------------------------------------------
# Train Accuracy: 0.8435087719298245
# Train Loss: 24.075707137584686
# --------------------------------------------------
# Validation Accuracy: 0.827
# Non-zero kernels: 0.020673076923076922
# Linear sparsity: 0.017287234042553192
# Overall sparsity: 0.018777078256160304
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [197.60310745239258, 229.5523864746094, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 95
# --------------------------------------------------
# Train Accuracy: 0.8455964912280701
# Train Loss: 24.011032044887543
# --------------------------------------------------
# Validation Accuracy: 0.8306666666666667
# Non-zero kernels: 0.020673076923076922
# Linear sparsity: 0.017332567698259187
# Overall sparsity: 0.018802464121310588
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [197.6924591064453, 229.82214965820313, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 96
# --------------------------------------------------
# Train Accuracy: 0.846561403508772
# Train Loss: 23.87586173415184
# --------------------------------------------------
# Validation Accuracy: 0.8213333333333334
# Non-zero kernels: 0.020913461538461537
# Linear sparsity: 0.01739301257253385
# Overall sparsity: 0.018942086379637152
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [197.8342170715332, 230.00704040527347, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 97
# --------------------------------------------------
# Train Accuracy: 0.8468421052631578
# Train Loss: 23.70226353406906
# --------------------------------------------------
# Validation Accuracy: 0.832
# Non-zero kernels: 0.020673076923076922
# Linear sparsity: 0.01745345744680851
# Overall sparsity: 0.018870159761711344
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [197.91641998291016, 230.2491638183594, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 98
# --------------------------------------------------
# Train Accuracy: 0.8453859649122807
# Train Loss: 23.85604965686798
# --------------------------------------------------
# Validation Accuracy: 0.8313333333333334
# Non-zero kernels: 0.020673076923076922
# Linear sparsity: 0.017491235493230173
# Overall sparsity: 0.018891314649336584
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [198.0077247619629, 230.49205627441407, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 99
# --------------------------------------------------
# Train Accuracy: 0.8459298245614035
# Train Loss: 23.910453349351883
# --------------------------------------------------
# Validation Accuracy: 0.8273333333333334
# Non-zero kernels: 0.020673076923076922
# Linear sparsity: 0.0175894584139265
# Overall sparsity: 0.0189463173571622
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [198.09935760498047, 230.7143768310547, 0.0]
# Learning rate: 0.07

# %%
print(best_model.best_model)

torch.save(best_model.best_model.state_dict(), '../checkpoints/mnist_conv_sparse_linbreg_ggmodel_lambda_4.pth')
# Out:
# mnist_conv(
#   (act_fn): ReLU()
#   (layers1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#   )
#   (layers2): Sequential(
#     (0): Linear(in_features=1024, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
model = best_model.best_model
model.eval()
# Out:
# mnist_conv(
#   (act_fn): ReLU()
#   (layers1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#   )
#   (layers2): Sequential(
#     (0): Linear(in_features=1024, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
train.test(conf, model, test_loader)
# Out:
# --------------------------------------------------
# Test Accuracy: 0.8514
# {'acc': 0.8514, 'loss': 4.152243971824646}
