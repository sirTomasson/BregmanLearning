# %%
# Various torch packages
import torch
import torch.nn as nn
import torch.nn.functional as F

# torchvision
from torchvision import datasets, transforms

# ------------------------
# get up one directory 
import sys, os
sys.path.append(os.path.abspath('../'))
# ------------------------

# custom packages
import matplotlib.pyplot as plt
import models.aux_funs as maf
import optimizers as op
import regularizers as reg
import train
import math
import utils.configuration as cf
import utils.datasets as ud
from models.mnist_conv import mnist_conv

# %% [markdown]
# # Fix the random seed

# %%
random_seed = 0
cf.seed_torch(random_seed)

# %% [markdown]
# # Configure the experiment (current best)

# %%
conf_args = {#
    # data specification
    'data_file':"../../Data",'train_split':0.95, 'data_set':"Fashion-MNIST", 'download':True,
    # cuda
    'use_cuda':True, 'num_workers':4, 'cuda_device':0, 'pin_memory':True,
    #
    'epochs':100,
    # optimizer
    'delta': 1.0, 'lr':0.0001, 'lamda_0':0.35, 'lamda_1':0.35, 'optim':"AdaBreg", 'row_group':True,
    'reg':reg.reg_l1_l2, 'beta':0.0,
    'conv_group':True,
    # initialization
    'sparse_init':0.05, 'r':[4.4,4.4,4.4],
    # misc
    'random_seed':random_seed, 'eval_acc':True,
}

conf = cf.Conf(**conf_args)

# %%
conf_args = {#
    # data specification
    'data_file':"../../datasets",'train_split':0.95, 'data_set':"Fashion-MNIST", 'download':True,
    # cuda
    'use_cuda':True, 'num_workers':4, 'cuda_device':0, 'pin_memory':True, 'train_split':0.95,
    #
    'epochs':100,
    # optimizer
    'delta':1.0, 'lr':0.07, 'lamda_0':.5, 'lamda_1':.5, 'optim':"LinBreg", 'conv_group':True,
    'beta':0.0,
    # initialization
    'sparse_init':0.5, 'r':[1.4, 1.4, 1.4],
    # misc
    'random_seed':random_seed, 'eval_acc':True,
}

conf = cf.Conf(**conf_args)

# %% [markdown]
# # Initiate the model

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    

model = mnist_conv(**model_kwargs)
best_model = train.best_model(mnist_conv(**model_kwargs).to(conf.device))

# %% [markdown]
# # Weight initialization

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    
def init_weights(conf, model):
    # sparsify
    maf.sparse_bias_uniform_(model, 0,conf.r[0])
    maf.sparse_bias_uniform_(model, 0,conf.r[0], ltype=torch.nn.Conv2d)
    maf.sparse_weight_normal_(model, conf.r[1])
    maf.sparse_weight_normal_(model, conf.r[2], ltype=torch.nn.Conv2d)
    #
    maf.sparsify_(model, conf.sparse_init, ltype = nn.Conv2d, conv_group=conf.conv_group)
    maf.sparsify_(model, conf.sparse_init, ltype = nn.Linear)
    model = model.to(conf.device)    
    return model

model = init_weights(conf,model)

# %% [markdown]
# # Optimizer

# %%
def init_opt(conf, model):
    # -----------------------------------------------------------------------------------
    # Get access to different model parameters
    # -----------------------------------------------------------------------------------
    weights_conv = maf.get_weights_conv(model)
    weights_linear = maf.get_weights_linear(model)
    biases = maf.get_bias(model)
    
    # -----------------------------------------------------------------------------------
    # Initialize optimizer
    # -----------------------------------------------------------------------------------
    if conf.conv_group:
        reg2 = reg.reg_l1_l2_conv(lamda=conf.lamda_0)
    else:
        reg2 = reg.reg_l1(lamda=conf.lamda_0)
    
    if conf.optim == "SGD":
        opt = torch.optim.SGD(model.parameters(), lr=conf.lr, momentum=conf.beta)
    elif conf.optim == "LinBreg":
        opt = op.LinBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])
    elif conf.optim == "ProxSGD":
        opt = op.ProxSGD([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])            
    elif conf.optim == "AdaBreg":
        opt = op.AdaBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2,'delta':conf.delta},
                           {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1),'delta':conf.delta},
                           {'params': biases, 'lr': conf.lr}])
    elif conf.optim == "L1SGD":
        def weight_reg(model):
            reg1 =  reg.reg_l1(lamda=conf.lamda_1)
        
            loss1 = reg1(model.layers2[0].weight) + reg1(model.layers2[2].weight)
            loss2 = reg2(model.layers1[0].weight) + reg2(model.layers1[3].weight)
            return loss1 + loss2
        
        conf.weight_reg = weight_reg
        
        opt = torch.optim.SGD(model.parameters(), lr=lr, momentum=beta)
    else:
        raise ValueError("Unknown Optimizer specified")

    # learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, factor=0.5, patience=5,threshold=0.01)
    
    return opt, scheduler

# %% [markdown]
# # Dataset

# %%
train_loader, valid_loader, test_loader = ud.get_data_set(conf)

# %% [markdown]
# # History and Runs

# %%
# Initialize history
tracked = ['loss', 'node_sparse']
train_hist = {}
val_hist = {}

# %% [markdown]
# # Training

# %%
# -----------------------------------------------------------------------------------
# Reinit weigts and the corresponding optimizer
# -----------------------------------------------------------------------------------
model = init_weights(conf, model)
opt, scheduler = init_opt(conf, model)

# -----------------------------------------------------------------------------------
# train the model
# -----------------------------------------------------------------------------------
for epoch in range(conf.epochs):
    print(25*"<>")
    print(50*"|")
    print(25*"<>")
    print('Epoch:', epoch)

    # ------------------------------------------------------------------------
    # train step, log the accuracy and loss
    # ------------------------------------------------------------------------
    train_data = train.train_step(conf, model, opt, train_loader)

    # update history
    for key in tracked:
        if key in train_data:
            var_list = train_hist.setdefault(key, [])
            var_list.append(train_data[key])           

    # ------------------------------------------------------------------------
    # validation step
    val_data = train.validation_step(conf, model, opt, valid_loader)

    # update validation history
    for key in tracked:
        if key in val_data:
            var = val_data[key]
            if isinstance(var, list):
                for i, var_loc in enumerate(var):
                    key_loc = key+"_" + str(i)
                    var_list = val_hist.setdefault(key_loc, [])
                    val_hist[key_loc].append(var_loc)
            else:
                var_list = val_hist.setdefault(key, [])
                var_list.append(var)   


    scheduler.step(train_data['loss'])
    print("Learning rate:",opt.param_groups[0]['lr'])
    best_model(train_data['acc'], val_data['acc'], model=model)
# Out:
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch:
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [314.7176971435547, 377.8232349395752, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 61
# --------------------------------------------------
# Train Accuracy: 0.7306842105263158
# Train Loss: 42.56686294078827
# --------------------------------------------------
# Validation Accuracy: 0.7233333333333334
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.050577248549323016
# Overall sparsity: 0.049794374492282696
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [314.7895612716675, 378.1837438583374, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 62
# --------------------------------------------------
# Train Accuracy: 0.7339473684210527
# Train Loss: 42.04455208778381
# --------------------------------------------------
# Validation Accuracy: 0.7246666666666667
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.05063769342359768
# Overall sparsity: 0.04982822231248308
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [314.85525703430176, 378.5289560317993, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 63
# --------------------------------------------------
# Train Accuracy: 0.7366140350877193
# Train Loss: 41.53400254249573
# --------------------------------------------------
# Validation Accuracy: 0.7253333333333334
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.05068302707930367
# Overall sparsity: 0.04985360817763336
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [314.92589950561523, 378.88122444152833, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 64
# --------------------------------------------------
# Train Accuracy: 0.7393859649122807
# Train Loss: 41.03290939331055
# --------------------------------------------------
# Validation Accuracy: 0.7266666666666667
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.05079636121856867
# Overall sparsity: 0.04991707284050907
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [314.99634170532227, 379.2349655151367, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 65
# --------------------------------------------------
# Train Accuracy: 0.7420350877192983
# Train Loss: 40.519621431827545
# --------------------------------------------------
# Validation Accuracy: 0.7303333333333333
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.05089458413926499
# Overall sparsity: 0.04997207554833469
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.06531858444214, 379.606477355957, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 66
# --------------------------------------------------
# Train Accuracy: 0.7452105263157894
# Train Loss: 40.01441824436188
# --------------------------------------------------
# Validation Accuracy: 0.7326666666666667
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.050985251450676984
# Overall sparsity: 0.050022847278635256
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.12793350219727, 379.9685817718506, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 67
# --------------------------------------------------
# Train Accuracy: 0.747859649122807
# Train Loss: 39.51687651872635
# --------------------------------------------------
# Validation Accuracy: 0.7346666666666667
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.0511061411992263
# Overall sparsity: 0.050090542919036016
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.19704723358154, 380.315799331665, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 68
# --------------------------------------------------
# Train Accuracy: 0.7509122807017544
# Train Loss: 39.02288019657135
# --------------------------------------------------
# Validation Accuracy: 0.7373333333333333
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.05123458655705996
# Overall sparsity: 0.050162469536961816
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.266725063324, 380.6296676635742, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 69
# --------------------------------------------------
# Train Accuracy: 0.7539473684210526
# Train Loss: 38.524914026260376
# --------------------------------------------------
# Validation Accuracy: 0.742
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.051370587524177946
# Overall sparsity: 0.05023862713241267
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.3241262435913, 380.98182258605954, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 70
# --------------------------------------------------
# Train Accuracy: 0.7577017543859649
# Train Loss: 38.01325798034668
# --------------------------------------------------
# Validation Accuracy: 0.7433333333333333
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.05147636605415861
# Overall sparsity: 0.050297860817763336
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.3997654914856, 381.33783740997313, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 71
# --------------------------------------------------
# Train Accuracy: 0.7609473684210526
# Train Loss: 37.539689779281616
# --------------------------------------------------
# Validation Accuracy: 0.747
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.05153681092843327
# Overall sparsity: 0.05033170863796371
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.452166557312, 381.75464401245114, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 72
# --------------------------------------------------
# Train Accuracy: 0.7643157894736842
# Train Loss: 37.0707648396492
# --------------------------------------------------
# Validation Accuracy: 0.7486666666666667
# Non-zero kernels: 0.04879807692307692
# Linear sparsity: 0.05168036750483559
# Overall sparsity: 0.050412097210939616
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.5136299133301, 382.1931800842285, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 73
# --------------------------------------------------
# Train Accuracy: 0.7664912280701754
# Train Loss: 36.61854714155197
# --------------------------------------------------
# Validation Accuracy: 0.7476666666666667
# Non-zero kernels: 0.04903846153846154
# Linear sparsity: 0.05182392408123791
# Overall sparsity: 0.050598260222041704
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.5754203796387, 382.62696037292477, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 74
# --------------------------------------------------
# Train Accuracy: 0.7696315789473684
# Train Loss: 36.17423301935196
# --------------------------------------------------
# Validation Accuracy: 0.7516666666666667
# Non-zero kernels: 0.04903846153846154
# Linear sparsity: 0.05194481382978723
# Overall sparsity: 0.050665955862442456
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.6388330459595, 383.0648302078247, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 75
# --------------------------------------------------
# Train Accuracy: 0.7720175438596492
# Train Loss: 35.74904930591583
# --------------------------------------------------
# Validation Accuracy: 0.7553333333333333
# Non-zero kernels: 0.04903846153846154
# Linear sparsity: 0.05203548114119923
# Overall sparsity: 0.050716727592743024
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.70215225219727, 383.51764965057373, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 76
# --------------------------------------------------
# Train Accuracy: 0.7750877192982456
# Train Loss: 35.33961707353592
# --------------------------------------------------
# Validation Accuracy: 0.7563333333333333
# Non-zero kernels: 0.04903846153846154
# Linear sparsity: 0.052126148452611216
# Overall sparsity: 0.05076749932304359
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.7672472000122, 383.96883354187014, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 77
# --------------------------------------------------
# Train Accuracy: 0.7769473684210526
# Train Loss: 34.948902904987335
# --------------------------------------------------
# Validation Accuracy: 0.758
# Non-zero kernels: 0.04903846153846154
# Linear sparsity: 0.052262149419729204
# Overall sparsity: 0.05084365691849445
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.814190864563, 384.3976551055908, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 78
# --------------------------------------------------
# Train Accuracy: 0.7798421052631579
# Train Loss: 34.580338060855865
# --------------------------------------------------
# Validation Accuracy: 0.761
# Non-zero kernels: 0.04903846153846154
# Linear sparsity: 0.05239059477756286
# Overall sparsity: 0.050915583536420256
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.86620140075684, 384.8351177215576, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 79
# --------------------------------------------------
# Train Accuracy: 0.7823157894736842
# Train Loss: 34.227919816970825
# --------------------------------------------------
# Validation Accuracy: 0.765
# Non-zero kernels: 0.04903846153846154
# Linear sparsity: 0.052556818181818184
# Overall sparsity: 0.051008665041971296
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.92210721969604, 385.2635921478271, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 80
# --------------------------------------------------
# Train Accuracy: 0.7849298245614035
# Train Loss: 33.87978380918503
# --------------------------------------------------
# Validation Accuracy: 0.7653333333333333
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05267015232108317
# Overall sparsity: 0.05117790414297319
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.99366092681885, 385.6961734771728, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 81
# --------------------------------------------------
# Train Accuracy: 0.7869122807017543
# Train Loss: 33.539774000644684
# --------------------------------------------------
# Validation Accuracy: 0.7666666666666667
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.052813708897485497
# Overall sparsity: 0.051258292715949096
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.05019760131836, 386.11639804840087, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 82
# --------------------------------------------------
# Train Accuracy: 0.7896491228070175
# Train Loss: 33.217624604701996
# --------------------------------------------------
# Validation Accuracy: 0.7726666666666666
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05288170938104449
# Overall sparsity: 0.05129637151367452
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.1197552680969, 386.5510822296142, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 83
# --------------------------------------------------
# Train Accuracy: 0.7915438596491228
# Train Loss: 32.90791690349579
# --------------------------------------------------
# Validation Accuracy: 0.7756666666666666
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.052949709864603484
# Overall sparsity: 0.051334450311399944
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.1759214401245, 386.9574159622192, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 84
# --------------------------------------------------
# Train Accuracy: 0.7932456140350878
# Train Loss: 32.59928059577942
# --------------------------------------------------
# Validation Accuracy: 0.7766666666666666
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.0530479327852998
# Overall sparsity: 0.05138945301922556
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.22873306274414, 387.3803215026855, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 85
# --------------------------------------------------
# Train Accuracy: 0.7956842105263158
# Train Loss: 32.311434268951416
# --------------------------------------------------
# Validation Accuracy: 0.7786666666666666
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05316882253384913
# Overall sparsity: 0.05145714865962632
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.2804431915283, 387.815629196167, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 86
# --------------------------------------------------
# Train Accuracy: 0.7974736842105263
# Train Loss: 32.02785959839821
# --------------------------------------------------
# Validation Accuracy: 0.781
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.053335045938104446
# Overall sparsity: 0.05155023016517736
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.3358516693115, 388.23943328857416, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 87
# --------------------------------------------------
# Train Accuracy: 0.7995263157894736
# Train Loss: 31.765842497348785
# --------------------------------------------------
# Validation Accuracy: 0.7806666666666666
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.0534861581237911
# Overall sparsity: 0.05163484971567831
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.3827152252197, 388.6703243255615, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 88
# --------------------------------------------------
# Train Accuracy: 0.8010175438596491
# Train Loss: 31.505420237779617
# --------------------------------------------------
# Validation Accuracy: 0.782
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05359949226305609
# Overall sparsity: 0.051698314378554024
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.4361209869385, 389.10414466857907, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 89
# --------------------------------------------------
# Train Accuracy: 0.8022105263157895
# Train Loss: 31.24502384662628
# --------------------------------------------------
# Validation Accuracy: 0.785
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05378838249516441
# Overall sparsity: 0.05180408881668021
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.4754776954651, 389.5291851043701, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 90
# --------------------------------------------------
# Train Accuracy: 0.8038421052631579
# Train Loss: 31.002469897270203
# --------------------------------------------------
# Validation Accuracy: 0.787
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05389416102514507
# Overall sparsity: 0.05186332250203087
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.5275549888611, 389.93977794647213, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 91
# --------------------------------------------------
# Train Accuracy: 0.8050701754385965
# Train Loss: 30.783422082662582
# --------------------------------------------------
# Validation Accuracy: 0.788
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05399993955512573
# Overall sparsity: 0.051922556187381536
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.56055307388306, 390.36245384216306, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 92
# --------------------------------------------------
# Train Accuracy: 0.8064561403508772
# Train Loss: 30.545852214097977
# --------------------------------------------------
# Validation Accuracy: 0.7903333333333333
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.054098162475822054
# Overall sparsity: 0.05197755889520715
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.6047263145447, 390.7788265228271, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 93
# --------------------------------------------------
# Train Accuracy: 0.8075438596491228
# Train Loss: 30.334699630737305
# --------------------------------------------------
# Validation Accuracy: 0.793
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05421149661508704
# Overall sparsity: 0.052041023558082856
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.64401960372925, 391.18309211730957, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 94
# --------------------------------------------------
# Train Accuracy: 0.8095964912280702
# Train Loss: 30.11972215771675
# --------------------------------------------------
# Validation Accuracy: 0.7956666666666666
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.0543399419729207
# Overall sparsity: 0.052112950176008664
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.68310260772705, 391.58038024902345, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 95
# --------------------------------------------------
# Train Accuracy: 0.8108947368421052
# Train Loss: 29.92690932750702
# --------------------------------------------------
# Validation Accuracy: 0.7986666666666666
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.054491054158607354
# Overall sparsity: 0.052197569726509616
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.72906494140625, 391.994189453125, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 96
# --------------------------------------------------
# Train Accuracy: 0.8122631578947368
# Train Loss: 29.72782576084137
# --------------------------------------------------
# Validation Accuracy: 0.799
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.054566610251450674
# Overall sparsity: 0.05223987950176009
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.7518424987793, 392.4154541015625, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 97
# --------------------------------------------------
# Train Accuracy: 0.8132982456140351
# Train Loss: 29.542027294635773
# --------------------------------------------------
# Validation Accuracy: 0.801
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05463461073500967
# Overall sparsity: 0.05227795829948551
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.7904748916626, 392.81636848449705, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 98
# --------------------------------------------------
# Train Accuracy: 0.8146842105263158
# Train Loss: 29.36077904701233
# --------------------------------------------------
# Validation Accuracy: 0.8016666666666666
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.05474038926499033
# Overall sparsity: 0.052337191984836176
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.82656049728394, 393.21132812499997, 0.0]
# Learning rate: 0.0001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 99
# --------------------------------------------------
# Train Accuracy: 0.8158771929824561
# Train Loss: 29.174792617559433
# --------------------------------------------------
# Validation Accuracy: 0.805
# Non-zero kernels: 0.04927884615384615
# Linear sparsity: 0.054891501450676984
# Overall sparsity: 0.05242181153533713
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.85872745513916, 393.6151397705078, 0.0]
# Learning rate: 0.0001

# %%
print(best_model.best_model)

torch.save(best_model.best_model.state_dict(), '../checkpoints/mnist_conv_sparse_adabreg_ggmodel_lambda_35_5pc.pth')
# Out:
# mnist_conv(
#   (act_fn): ReLU()
#   (layers1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#   )
#   (layers2): Sequential(
#     (0): Linear(in_features=1024, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
model = best_model.best_model
model.eval()
# Out:
# mnist_conv(
#   (act_fn): ReLU()
#   (layers1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#   )
#   (layers2): Sequential(
#     (0): Linear(in_features=1024, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
train.test(conf, model, test_loader)
# Out:
# --------------------------------------------------
# Test Accuracy: 0.8942
# {'acc': 0.8942, 'loss': 3.059849500656128}
