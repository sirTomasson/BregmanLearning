# %%
# Various torch packages
import torch
import torch.nn as nn
import torch.nn.functional as F

# torchvision
from torchvision import datasets, transforms

# ------------------------
# get up one directory 
import sys, os
sys.path.append(os.path.abspath('../'))
# ------------------------

# custom packages
import matplotlib.pyplot as plt
import models.aux_funs as maf
import optimizers as op
import regularizers as reg
import train
import math
import utils.configuration as cf
import utils.datasets as ud
from models.mnist_conv import mnist_conv

# %% [markdown]
# # Fix the random seed

# %%
random_seed = 2
cf.seed_torch(random_seed)

# %% [markdown]
# # Configure the experiment

# %%
conf_args = {#
    # data specification
    'data_file':"../../Data",'train_split':0.95, 'data_set':"Fashion-MNIST", 'download':True,
    # cuda
    'use_cuda':False, 'num_workers':4, 'cuda_device':0, 'pin_memory':True,
    #
    'epochs':100,
    # optimizer
    'delta':1.0, 'lr':0.001, 'lamda_0':0.05, 'lamda_1':0.05, 'optim':"AdaBreg", 'row_group':True,
    'reg':reg.reg_l1_l2, 'beta':0.0,
    'conv_group':True,
    # initialization
    'sparse_init':0.01, 'r':[1,1,1],
    # misc
    'random_seed':random_seed, 'eval_acc':True,
}

conf = cf.Conf(**conf_args)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       1 conf_args = {#
#       2     # data specification
#       3     'data_file':"../../Data",'train_split':0.95, 'data_set':"Fashion-MNIST", 'download':True,
#       4     # cuda
#       5     'use_cuda':False, 'num_workers':4, 'cuda_device':0, 'pin_memory':True,
#       6     #
#       7     'epochs':100,
#       8     # optimizer
#       9     'delta':1.0, 'lr':0.001, 'lamda_0':0.05, 'lamda_1':0.05, 'optim':"AdaBreg", 'row_group':True,
# ---> 10     'reg':reg.reg_l1_l2, 'beta':0.0,
#      11     'conv_group':True,
#      12     # initialization
#      13     'sparse_init':0.01, 'r':[1,1,1],
#      14     # misc
#      15     'random_seed':random_seed, 'eval_acc':True,
#      16 }
#      18 conf = cf.Conf(**conf_args)
#
# NameError: name 'reg' is not defined

# %% [markdown]
# # Initiate the model

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    

model = mnist_conv(**model_kwargs)
best_model = train.best_model(mnist_conv(**model_kwargs).to(conf.device))

# %% [markdown]
# # Weight initialization

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    
def init_weights(conf, model):
    # sparsify
    maf.sparse_bias_uniform_(model, 0,conf.r[0])
    maf.sparse_bias_uniform_(model, 0,conf.r[0],ltype=torch.nn.Conv2d)
    maf.sparse_weight_normal_(model, conf.r[1])
    maf.sparse_weight_normal_(model, conf.r[2],ltype=torch.nn.Conv2d)
    #
    maf.sparsify_(model, conf.sparse_init, ltype = nn.Conv2d, conv_group=conf.conv_group)
    model = model.to(conf.device)
    
    return model

model = init_weights(conf,model)

# %% [markdown]
# # Optimizer

# %%
def init_opt(conf, model):
    # -----------------------------------------------------------------------------------
    # Get access to different model parameters
    # -----------------------------------------------------------------------------------
    weights_conv = maf.get_weights_conv(model)
    weights_linear = maf.get_weights_linear(model)
    biases = maf.get_bias(model)
    
    # -----------------------------------------------------------------------------------
    # Initialize optimizer
    # -----------------------------------------------------------------------------------
    if conf.conv_group:
        reg2 = reg.reg_l1_l2_conv(lamda=conf.lamda_0)
    else:
        reg2 = reg.reg_l1(lamda=conf.lamda_0)
    
    if conf.optim == "SGD":
        opt = torch.optim.SGD(model.parameters(), lr=conf.lr, momentum=conf.beta)
    elif conf.optim == "LinBreg":
        opt = op.LinBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])
    elif conf.optim == "ProxSGD":
        opt = op.ProxSGD([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])            
    elif conf.optim == "AdaBreg":
        opt = op.AdaBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2,'delta':conf.delta},
                           {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1),'delta':conf.delta},
                           {'params': biases, 'lr': conf.lr}])
    elif conf.optim == "L1SGD":
        def weight_reg(model):
            reg1 =  reg.reg_l1(lamda=conf.lamda_1)
        
            loss1 = reg1(model.layers2[0].weight) + reg1(model.layers2[2].weight)
            loss2 = reg2(model.layers1[0].weight) + reg2(model.layers1[3].weight)
            return loss1 + loss2
        
        conf.weight_reg = weight_reg
        
        opt = torch.optim.SGD(model.parameters(), lr=lr, momentum=beta)
    else:
        raise ValueError("Unknown Optimizer specified")

    # learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, factor=0.5, patience=5,threshold=0.01)
    
    return opt, scheduler

# %% [markdown]
# # Dataset

# %%
train_loader, valid_loader, test_loader = ud.get_data_set(conf)

# %% [markdown]
# # History and Runs

# %%
# Initialize history
tracked = ['loss', 'node_sparse']
train_hist = {}
val_hist = {}

# %% [markdown]
# # Training

# %%
# -----------------------------------------------------------------------------------
# Reinit weigts and the corresponding optimizer
# -----------------------------------------------------------------------------------
model = init_weights(conf, model)
opt, scheduler = init_opt(conf, model)

# -----------------------------------------------------------------------------------
# train the model
# -----------------------------------------------------------------------------------
for epoch in range(conf.epochs):
    print(25*"<>")
    print(50*"|")
    print(25*"<>")
    print('Epoch:', epoch)

    # ------------------------------------------------------------------------
    # train step, log the accuracy and loss
    # ------------------------------------------------------------------------
    train_data = train.train_step(conf, model, opt, train_loader)

    # update history
    for key in tracked:
        if key in train_data:
            var_list = train_hist.setdefault(key, [])
            var_list.append(train_data[key])           

    # ------------------------------------------------------------------------
    # validation step
    val_data = train.validation_step(conf, model, opt, valid_loader)

    # update validation history
    for key in tracked:
        if key in val_data:
            var = val_data[key]
            if isinstance(var, list):
                for i, var_loc in enumerate(var):
                    key_loc = key+"_" + str(i)
                    var_list = val_hist.setdefault(key_loc, [])
                    val_hist[key_loc].append(var_loc)
            else:
                var_list = val_hist.setdefault(key, [])
                var_list.append(var)   


    scheduler.step(train_data['loss'])
    print("Learning rate:",opt.param_groups[0]['lr'])
    best_model(train_data['acc'], val_data['acc'], model=model)
# Out:
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 0
# --------------------------------------------------
# Train Accuracy: 0.6108421052631579
# Train Loss: 467.861740231514
# --------------------------------------------------
# Validation Accuracy: 0.7983333333333333
# Non-zero kernels: 0.08365384615384615
# Linear sparsity: 0.924851910058027
# Overall sparsity: 0.5547065393988627
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [6.476309061050415, 251.6398826599121, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 1
# --------------------------------------------------
# Train Accuracy: 0.8256666666666667
# Train Loss: 210.23116773366928
# --------------------------------------------------
# Validation Accuracy: 0.8373333333333334
# Non-zero kernels: 0.10048076923076923
# Linear sparsity: 0.9120149298839458
# Overall sparsity: 0.5549223192526401
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [8.365232229232788, 258.82473602294925, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 2
# --------------------------------------------------
# Train Accuracy: 0.8544736842105263
# Train Loss: 180.33581212162971
# --------------------------------------------------
# Validation Accuracy: 0.8516666666666667
# Non-zero kernels: 0.10961538461538461
# Linear sparsity: 0.9041646518375241
# Overall sparsity: 0.554545762252911
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [10.121110916137695, 264.88661956787115, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 3
# --------------------------------------------------
# Train Accuracy: 0.8671578947368421
# Train Loss: 162.04255566000938
# --------------------------------------------------
# Validation Accuracy: 0.861
# Non-zero kernels: 0.13557692307692307
# Linear sparsity: 0.8986717238878144
# Overall sparsity: 0.5628934809098294
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [12.17175567150116, 270.56281661987305, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 4
# --------------------------------------------------
# Train Accuracy: 0.879280701754386
# Train Loss: 149.03672289848328
# --------------------------------------------------
# Validation Accuracy: 0.8663333333333333
# Non-zero kernels: 0.14326923076923076
# Linear sparsity: 0.8935641320116054
# Overall sparsity: 0.5634181221229353
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [14.044668793678284, 275.93985137939455, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 5
# --------------------------------------------------
# Train Accuracy: 0.887140350877193
# Train Loss: 139.25401194393635
# --------------------------------------------------
# Validation Accuracy: 0.872
# Non-zero kernels: 0.1466346153846154
# Linear sparsity: 0.8907081117021277
# Overall sparsity: 0.563299654752234
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [15.552399754524231, 280.4832672119141, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 6
# --------------------------------------------------
# Train Accuracy: 0.8925614035087719
# Train Loss: 132.06891983747482
# --------------------------------------------------
# Validation Accuracy: 0.8756666666666667
# Non-zero kernels: 0.1485576923076923
# Linear sparsity: 0.8889627659574468
# Overall sparsity: 0.5631684944489574
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [17.339661836624146, 284.80511169433595, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 7
# --------------------------------------------------
# Train Accuracy: 0.8977017543859649
# Train Loss: 124.68502616882324
# --------------------------------------------------
# Validation Accuracy: 0.8833333333333333
# Non-zero kernels: 0.14278846153846153
# Linear sparsity: 0.8888947654738878
# Overall sparsity: 0.5605918291362036
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [18.546350598335266, 288.82200241088873, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 8
# --------------------------------------------------
# Train Accuracy: 0.9041228070175439
# Train Loss: 117.24544257670641
# --------------------------------------------------
# Validation Accuracy: 0.8753333333333333
# Non-zero kernels: 0.14158653846153846
# Linear sparsity: 0.8884867625725339
# Overall sparsity: 0.5598344841592201
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [20.01892840862274, 292.6464294433594, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 9
# --------------------------------------------------
# Train Accuracy: 0.908140350877193
# Train Loss: 112.92545107007027
# --------------------------------------------------
# Validation Accuracy: 0.8896666666666667
# Non-zero kernels: 0.14158653846153846
# Linear sparsity: 0.8894765473887815
# Overall sparsity: 0.5603887422150013
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [21.10844075679779, 296.15458984375005, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 10
# --------------------------------------------------
# Train Accuracy: 0.9106842105263158
# Train Loss: 107.79281673580408
# --------------------------------------------------
# Validation Accuracy: 0.892
# Non-zero kernels: 0.14134615384615384
# Linear sparsity: 0.8897334381044487
# Overall sparsity: 0.5604268210127268
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [22.394355416297913, 299.5926246643067, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 11
# --------------------------------------------------
# Train Accuracy: 0.9146315789473685
# Train Loss: 103.22908279299736
# --------------------------------------------------
# Validation Accuracy: 0.8923333333333333
# Non-zero kernels: 0.14182692307692307
# Linear sparsity: 0.8900432180851063
# Overall sparsity: 0.560811839967506
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [23.53721833229065, 302.98982162475585, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 12
# --------------------------------------------------
# Train Accuracy: 0.9172807017543859
# Train Loss: 99.85570397228003
# --------------------------------------------------
# Validation Accuracy: 0.89
# Non-zero kernels: 0.14014423076923077
# Linear sparsity: 0.890443665377176
# Overall sparsity: 0.5602956607094504
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [24.266688108444214, 306.29573287963865, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 13
# --------------------------------------------------
# Train Accuracy: 0.9212631578947369
# Train Loss: 95.86465252190828
# --------------------------------------------------
# Validation Accuracy: 0.8913333333333333
# Non-zero kernels: 0.14302884615384615
# Linear sparsity: 0.8915241175048356
# Overall sparsity: 0.5621699837530463
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [25.284762263298035, 309.6039588928223, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 14
# --------------------------------------------------
# Train Accuracy: 0.9235087719298246
# Train Loss: 91.7960958108306
# --------------------------------------------------
# Validation Accuracy: 0.8946666666666667
# Non-zero kernels: 0.14326923076923076
# Linear sparsity: 0.8922947896518375
# Overall sparsity: 0.5627073178987273
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [26.1546893119812, 312.83998413085936, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 15
# --------------------------------------------------
# Train Accuracy: 0.9256666666666666
# Train Loss: 89.75369660556316
# --------------------------------------------------
# Validation Accuracy: 0.892
# Non-zero kernels: 0.14471153846153847
# Linear sparsity: 0.8925441247582205
# Overall sparsity: 0.563481586785811
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [27.301684141159058, 316.0400024414063, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 16
# --------------------------------------------------
# Train Accuracy: 0.9273508771929825
# Train Loss: 87.37407016009092
# --------------------------------------------------
# Validation Accuracy: 0.899
# Non-zero kernels: 0.146875
# Linear sparsity: 0.8933827973887815
# Overall sparsity: 0.5649031952342269
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [28.180492758750916, 319.2997871398926, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 17
# --------------------------------------------------
# Train Accuracy: 0.9311052631578948
# Train Loss: 83.45845214277506
# --------------------------------------------------
# Validation Accuracy: 0.8953333333333333
# Non-zero kernels: 0.1451923076923077
# Linear sparsity: 0.8945690280464217
# Overall sparsity: 0.5648270376387761
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [28.75820529460907, 322.41692199707035, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 18
# --------------------------------------------------
# Train Accuracy: 0.9338947368421052
# Train Loss: 80.28572994470596
# --------------------------------------------------
# Validation Accuracy: 0.8903333333333333
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.8951432543520309
# Overall sparsity: 0.5654659152450582
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [29.886196851730347, 325.48503189086915, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 19
# --------------------------------------------------
# Train Accuracy: 0.9347017543859649
# Train Loss: 79.37603896483779
# --------------------------------------------------
# Validation Accuracy: 0.8966666666666666
# Non-zero kernels: 0.14471153846153847
# Linear sparsity: 0.8959517045454546
# Overall sparsity: 0.5653897576496074
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [30.874903440475464, 328.5112106323242, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 20
# --------------------------------------------------
# Train Accuracy: 0.9368596491228071
# Train Loss: 75.99100459367037
# --------------------------------------------------
# Validation Accuracy: 0.891
# Non-zero kernels: 0.14471153846153847
# Linear sparsity: 0.8963068181818182
# Overall sparsity: 0.5655886135932846
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [31.69117832183838, 331.40145797729497, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 21
# --------------------------------------------------
# Train Accuracy: 0.9386842105263158
# Train Loss: 73.35694148391485
# --------------------------------------------------
# Validation Accuracy: 0.893
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.8970926015473888
# Overall sparsity: 0.5665575074465204
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [32.46870231628418, 334.368807220459, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 22
# --------------------------------------------------
# Train Accuracy: 0.9413333333333334
# Train Loss: 70.97976979613304
# --------------------------------------------------
# Validation Accuracy: 0.8963333333333333
# Non-zero kernels: 0.14375
# Linear sparsity: 0.897508160058027
# Overall sparsity: 0.5658382412672623
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [33.210981369018555, 337.38765106201174, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 23
# --------------------------------------------------
# Train Accuracy: 0.9426666666666667
# Train Loss: 68.44648980349302
# --------------------------------------------------
# Validation Accuracy: 0.894
# Non-zero kernels: 0.14423076923076922
# Linear sparsity: 0.8980068302707931
# Overall sparsity: 0.5663290346601679
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [34.18126726150513, 340.2982543945312, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 24
# --------------------------------------------------
# Train Accuracy: 0.9453859649122807
# Train Loss: 65.69244306907058
# --------------------------------------------------
# Validation Accuracy: 0.8983333333333333
# Non-zero kernels: 0.1449519230769231
# Linear sparsity: 0.89866416827853
# Overall sparsity: 0.5670144530192256
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [34.757336378097534, 343.18591384887696, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 25
# --------------------------------------------------
# Train Accuracy: 0.9467368421052632
# Train Loss: 64.56051580607891
# --------------------------------------------------
# Validation Accuracy: 0.8923333333333333
# Non-zero kernels: 0.1439903846153846
# Linear sparsity: 0.8992081721470019
# Overall sparsity: 0.5668959856485243
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [35.557276248931885, 345.991130065918, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 26
# --------------------------------------------------
# Train Accuracy: 0.9474912280701754
# Train Loss: 62.51450253650546
# --------------------------------------------------
# Validation Accuracy: 0.8976666666666666
# Non-zero kernels: 0.14350961538461537
# Linear sparsity: 0.9002055125725339
# Overall sparsity: 0.5672429258055781
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [35.97766709327698, 348.7448883056641, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 27
# --------------------------------------------------
# Train Accuracy: 0.9509298245614035
# Train Loss: 59.69951496645808
# --------------------------------------------------
# Validation Accuracy: 0.8906666666666667
# Non-zero kernels: 0.1439903846153846
# Linear sparsity: 0.9001828457446809
# Overall sparsity: 0.5674417817492553
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.66629433631897, 351.4696746826172, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 28
# --------------------------------------------------
# Train Accuracy: 0.9511578947368421
# Train Loss: 58.189402621239424
# --------------------------------------------------
# Validation Accuracy: 0.895
# Non-zero kernels: 0.14350961538461537
# Linear sparsity: 0.9004246252417795
# Overall sparsity: 0.5673656241538045
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [37.4028434753418, 354.27958755493165, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 29
# --------------------------------------------------
# Train Accuracy: 0.954140350877193
# Train Loss: 55.39937033504248
# --------------------------------------------------
# Validation Accuracy: 0.8886666666666667
# Non-zero kernels: 0.14423076923076922
# Linear sparsity: 0.9003717359767892
# Overall sparsity: 0.5676533306255077
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [38.080119609832764, 356.89317321777344, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 30
# --------------------------------------------------
# Train Accuracy: 0.9550701754385965
# Train Loss: 53.963072806596756
# --------------------------------------------------
# Validation Accuracy: 0.8963333333333333
# Non-zero kernels: 0.14302884615384615
# Linear sparsity: 0.9012406310444874
# Overall sparsity: 0.5676110208502573
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [38.76746320724487, 359.7056968688965, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 31
# --------------------------------------------------
# Train Accuracy: 0.9554736842105264
# Train Loss: 52.94735158607364
# --------------------------------------------------
# Validation Accuracy: 0.894
# Non-zero kernels: 0.1423076923076923
# Linear sparsity: 0.9015050773694391
# Overall sparsity: 0.5674417817492553
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [39.42364501953125, 362.34007263183594, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 32
# --------------------------------------------------
# Train Accuracy: 0.9567894736842105
# Train Loss: 51.50605035945773
# --------------------------------------------------
# Validation Accuracy: 0.898
# Non-zero kernels: 0.14350961538461537
# Linear sparsity: 0.9019735251450677
# Overall sparsity: 0.5682329745464392
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [40.06991147994995, 364.93319625854497, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 33
# --------------------------------------------------
# Train Accuracy: 0.9605438596491228
# Train Loss: 48.148242224007845
# --------------------------------------------------
# Validation Accuracy: 0.895
# Non-zero kernels: 0.14302884615384615
# Linear sparsity: 0.9024721953578336
# Overall sparsity: 0.5683006701868399
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [40.71652889251709, 367.50169296264653, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 34
# --------------------------------------------------
# Train Accuracy: 0.9608947368421052
# Train Loss: 47.041183875873685
# --------------------------------------------------
# Validation Accuracy: 0.8956666666666667
# Non-zero kernels: 0.14423076923076922
# Linear sparsity: 0.902479750967118
# Overall sparsity: 0.568833773354996
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [41.34298372268677, 370.1037208557129, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 35
# --------------------------------------------------
# Train Accuracy: 0.961280701754386
# Train Loss: 45.906409163028
# --------------------------------------------------
# Validation Accuracy: 0.8946666666666667
# Non-zero kernels: 0.14423076923076922
# Linear sparsity: 0.9030313104448743
# Overall sparsity: 0.5691426347143244
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [42.00605535507202, 372.75132904052737, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 36
# --------------------------------------------------
# Train Accuracy: 0.9636666666666667
# Train Loss: 44.78062555938959
# --------------------------------------------------
# Validation Accuracy: 0.896
# Non-zero kernels: 0.1423076923076923
# Linear sparsity: 0.9035602030947776
# Overall sparsity: 0.5685926076360682
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [42.66989612579346, 375.25224914550785, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 37
# --------------------------------------------------
# Train Accuracy: 0.9646666666666667
# Train Loss: 42.91769917495549
# --------------------------------------------------
# Validation Accuracy: 0.8976666666666666
# Non-zero kernels: 0.14326923076923076
# Linear sparsity: 0.9039530947775629
# Overall sparsity: 0.5692357162198755
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [43.36774802207947, 377.77257080078124, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 38
# --------------------------------------------------
# Train Accuracy: 0.9650350877192982
# Train Loss: 42.14852579496801
# --------------------------------------------------
# Validation Accuracy: 0.8933333333333333
# Non-zero kernels: 0.14350961538461537
# Linear sparsity: 0.9043837645067698
# Overall sparsity: 0.5695826563769293
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [43.98422718048096, 380.2191925048828, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 39
# --------------------------------------------------
# Train Accuracy: 0.9662982456140351
# Train Loss: 40.425352443009615
# --------------------------------------------------
# Validation Accuracy: 0.8903333333333333
# Non-zero kernels: 0.14471153846153847
# Linear sparsity: 0.9050562137330754
# Overall sparsity: 0.5704880855672895
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [44.5991051197052, 382.63217163085943, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 40
# --------------------------------------------------
# Train Accuracy: 0.966859649122807
# Train Loss: 39.34968583844602
# --------------------------------------------------
# Validation Accuracy: 0.887
# Non-zero kernels: 0.14423076923076922
# Linear sparsity: 0.9056757736943907
# Overall sparsity: 0.570623476848091
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [45.17894673347473, 385.10508422851564, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 41
# --------------------------------------------------
# Train Accuracy: 0.9694035087719298
# Train Loss: 37.901171575300395
# --------------------------------------------------
# Validation Accuracy: 0.893
# Non-zero kernels: 0.14447115384615383
# Linear sparsity: 0.9061291102514507
# Overall sparsity: 0.5709831099377201
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [45.848517656326294, 387.71013488769535, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 42
# --------------------------------------------------
# Train Accuracy: 0.9701052631578947
# Train Loss: 36.10403963364661
# --------------------------------------------------
# Validation Accuracy: 0.887
# Non-zero kernels: 0.1451923076923077
# Linear sparsity: 0.9065068907156673
# Overall sparsity: 0.571511982128351
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [46.44580864906311, 390.13115844726565, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 43
# --------------------------------------------------
# Train Accuracy: 0.971701754385965
# Train Loss: 34.30155840795487
# --------------------------------------------------
# Validation Accuracy: 0.8896666666666667
# Non-zero kernels: 0.1449519230769231
# Linear sparsity: 0.9068468931334622
# Overall sparsity: 0.5715966016788518
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [47.030296087265015, 392.3661819458008, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 44
# --------------------------------------------------
# Train Accuracy: 0.971719298245614
# Train Loss: 34.27462570741773
# --------------------------------------------------
# Validation Accuracy: 0.8906666666666667
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9076553433268859
# Overall sparsity: 0.5722608651502843
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [47.705310344696045, 394.9561401367188, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 45
# --------------------------------------------------
# Train Accuracy: 0.9724385964912281
# Train Loss: 33.32494448963553
# --------------------------------------------------
# Validation Accuracy: 0.889
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9082975701160542
# Overall sparsity: 0.5726204982399133
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [48.24149250984192, 397.420182800293, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 46
# --------------------------------------------------
# Train Accuracy: 0.9742982456140351
# Train Loss: 31.01175979524851
# --------------------------------------------------
# Validation Accuracy: 0.8826666666666667
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9084789047388782
# Overall sparsity: 0.5727220417005144
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [48.86672496795654, 399.5760803222656, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 47
# --------------------------------------------------
# Train Accuracy: 0.9740526315789474
# Train Loss: 30.828831520862877
# --------------------------------------------------
# Validation Accuracy: 0.8946666666666667
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9086073500967118
# Overall sparsity: 0.5727939683184403
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [49.41192007064819, 401.9648040771485, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 48
# --------------------------------------------------
# Train Accuracy: 0.9761052631578947
# Train Loss: 29.355673111975193
# --------------------------------------------------
# Validation Accuracy: 0.8846666666666667
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9089926861702128
# Overall sparsity: 0.5730097481722177
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [49.90675234794617, 404.2466018676758, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 49
# --------------------------------------------------
# Train Accuracy: 0.9757543859649123
# Train Loss: 29.325308991596103
# --------------------------------------------------
# Validation Accuracy: 0.8886666666666667
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9095215788201161
# Overall sparsity: 0.573305916598971
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [50.44131278991699, 406.48309631347655, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 50
# --------------------------------------------------
# Train Accuracy: 0.9751929824561404
# Train Loss: 30.096513079013675
# --------------------------------------------------
# Validation Accuracy: 0.8913333333333333
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9099673597678917
# Overall sparsity: 0.5735555442729489
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [50.96114540100098, 408.8158432006836, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 51
# --------------------------------------------------
# Train Accuracy: 0.9782982456140351
# Train Loss: 26.445897178724408
# --------------------------------------------------
# Validation Accuracy: 0.8946666666666667
# Non-zero kernels: 0.14471153846153847
# Linear sparsity: 0.910088249516441
# Overall sparsity: 0.573305916598971
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [51.44640016555786, 410.79006805419925, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 52
# --------------------------------------------------
# Train Accuracy: 0.9791578947368421
# Train Loss: 25.44847010774538
# --------------------------------------------------
# Validation Accuracy: 0.8926666666666667
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9106020309477756
# Overall sparsity: 0.5739109463850528
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [52.04334378242493, 412.9432861328125, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 53
# --------------------------------------------------
# Train Accuracy: 0.9791228070175438
# Train Loss: 24.971845079679042
# --------------------------------------------------
# Validation Accuracy: 0.8933333333333333
# Non-zero kernels: 0.14471153846153847
# Linear sparsity: 0.9107078094777563
# Overall sparsity: 0.573652856756025
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [52.652684450149536, 415.0012878417969, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 54
# --------------------------------------------------
# Train Accuracy: 0.9790350877192983
# Train Loss: 25.52561274729669
# --------------------------------------------------
# Validation Accuracy: 0.8936666666666667
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9113349250483559
# Overall sparsity: 0.5743213512049824
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [53.134604930877686, 417.1581909179688, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 55
# --------------------------------------------------
# Train Accuracy: 0.9802982456140351
# Train Loss: 23.408218297176063
# --------------------------------------------------
# Validation Accuracy: 0.8903333333333333
# Non-zero kernels: 0.1451923076923077
# Linear sparsity: 0.9117580391682786
# Overall sparsity: 0.5744525115082588
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [53.54609155654907, 419.2499664306641, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 56
# --------------------------------------------------
# Train Accuracy: 0.9810526315789474
# Train Loss: 22.61197863612324
# --------------------------------------------------
# Validation Accuracy: 0.8946666666666667
# Non-zero kernels: 0.1451923076923077
# Linear sparsity: 0.9121207084139265
# Overall sparsity: 0.5746555984294611
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [53.9002161026001, 421.23993530273435, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 57
# --------------------------------------------------
# Train Accuracy: 0.9820526315789474
# Train Loss: 21.4363684207201
# --------------------------------------------------
# Validation Accuracy: 0.892
# Non-zero kernels: 0.14567307692307693
# Linear sparsity: 0.9122567093810445
# Overall sparsity: 0.5749433049011644
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [54.41810202598572, 423.15313720703125, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 58
# --------------------------------------------------
# Train Accuracy: 0.9815263157894737
# Train Loss: 21.80390552058816
# --------------------------------------------------
# Validation Accuracy: 0.888
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9126420454545454
# Overall sparsity: 0.5750533103168156
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [54.870957136154175, 425.19503784179693, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 59
# --------------------------------------------------
# Train Accuracy: 0.982701754385965
# Train Loss: 20.674166722223163
# --------------------------------------------------
# Validation Accuracy: 0.8906666666666667
# Non-zero kernels: 0.1451923076923077
# Linear sparsity: 0.9130198259187621
# Overall sparsity: 0.5751590847549418
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [55.35696625709534, 427.2382446289063, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 60
# --------------------------------------------------
# Train Accuracy: 0.9843508771929824
# Train Loss: 19.295541998464614
# --------------------------------------------------
# Validation Accuracy: 0.8903333333333333
# Non-zero kernels: 0.14567307692307693
# Linear sparsity: 0.9132842722437138
# Overall sparsity: 0.5755187178445708
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [55.76107978820801, 429.0391021728516, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 61
# --------------------------------------------------
# Train Accuracy: 0.9809824561403508
# Train Loss: 22.323478476144373
# --------------------------------------------------
# Validation Accuracy: 0.892
# Non-zero kernels: 0.1449519230769231
# Linear sparsity: 0.9132691610251451
# Overall sparsity: 0.5751929325751421
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [56.24229598045349, 431.5053756713868, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 62
# --------------------------------------------------
# Train Accuracy: 0.9833333333333333
# Train Loss: 19.465306274592876
# --------------------------------------------------
# Validation Accuracy: 0.897
# Non-zero kernels: 0.1451923076923077
# Linear sparsity: 0.9133447171179884
# Overall sparsity: 0.5753410167885188
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [56.62850904464722, 433.25026245117186, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 63
# --------------------------------------------------
# Train Accuracy: 0.985701754385965
# Train Loss: 17.458507926668972
# --------------------------------------------------
# Validation Accuracy: 0.8916666666666667
# Non-zero kernels: 0.1451923076923077
# Linear sparsity: 0.9138282761121856
# Overall sparsity: 0.5756117993501219
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [57.01322102546692, 434.94581298828126, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 64
# --------------------------------------------------
# Train Accuracy: 0.9852631578947368
# Train Loss: 18.17221043864265
# --------------------------------------------------
# Validation Accuracy: 0.8946666666666667
# Non-zero kernels: 0.14615384615384616
# Linear sparsity: 0.9139189434235977
# Overall sparsity: 0.5760856688329271
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [57.54347348213196, 436.8337646484375, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 65
# --------------------------------------------------
# Train Accuracy: 0.9841578947368421
# Train Loss: 18.94692226499319
# --------------------------------------------------
# Validation Accuracy: 0.8913333333333333
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.914221167794971
# Overall sparsity: 0.5761491334958029
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [57.89099740982056, 438.8994903564453, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 66
# --------------------------------------------------
# Train Accuracy: 0.9856491228070176
# Train Loss: 17.357521889265627
# --------------------------------------------------
# Validation Accuracy: 0.8926666666666667
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9147122823984526
# Overall sparsity: 0.576424147034931
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [58.25124502182007, 440.5851104736328, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 67
# --------------------------------------------------
# Train Accuracy: 0.987280701754386
# Train Loss: 15.484416010556743
# --------------------------------------------------
# Validation Accuracy: 0.8863333333333333
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9150296179883946
# Overall sparsity: 0.5766018480909829
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [58.6531138420105, 442.41619262695315, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 68
# --------------------------------------------------
# Train Accuracy: 0.9869298245614035
# Train Loss: 15.63954418245703
# --------------------------------------------------
# Validation Accuracy: 0.891
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9151429521276596
# Overall sparsity: 0.5766653127538587
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [58.99673843383789, 444.23243103027346, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 69
# --------------------------------------------------
# Train Accuracy: 0.9841578947368421
# Train Loss: 19.068530470132828
# --------------------------------------------------
# Validation Accuracy: 0.8893333333333333
# Non-zero kernels: 0.14543269230769232
# Linear sparsity: 0.9157247340425532
# Overall sparsity: 0.5767795491470349
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [59.41822266578674, 446.3287399291993, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 70
# --------------------------------------------------
# Train Accuracy: 0.987578947368421
# Train Loss: 14.972358873026678
# --------------------------------------------------
# Validation Accuracy: 0.8906666666666667
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9156038442940039
# Overall sparsity: 0.5769234023828865
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [59.67520761489868, 447.86218414306643, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 71
# --------------------------------------------------
# Train Accuracy: 0.9883157894736843
# Train Loss: 13.80378298391588
# --------------------------------------------------
# Validation Accuracy: 0.894
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9159665135396519
# Overall sparsity: 0.5771264893040888
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [59.81308078765869, 449.4725448608399, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 72
# --------------------------------------------------
# Train Accuracy: 0.9864385964912281
# Train Loss: 16.008269710699096
# --------------------------------------------------
# Validation Accuracy: 0.8886666666666667
# Non-zero kernels: 0.14567307692307693
# Linear sparsity: 0.9158002901353965
# Overall sparsity: 0.5769276333604116
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [60.184069871902466, 451.1290512084961, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 73
# --------------------------------------------------
# Train Accuracy: 0.9892280701754386
# Train Loss: 13.226039921864867
# --------------------------------------------------
# Validation Accuracy: 0.8903333333333333
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9165029617988395
# Overall sparsity: 0.5774268887083672
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [60.588924407958984, 452.6913208007813, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 74
# --------------------------------------------------
# Train Accuracy: 0.9881754385964913
# Train Loss: 14.241060164407827
# --------------------------------------------------
# Validation Accuracy: 0.8886666666666667
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9165256286266924
# Overall sparsity: 0.5774395816409423
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [61.10025978088379, 454.4054168701172, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 75
# --------------------------------------------------
# Train Accuracy: 0.9864561403508771
# Train Loss: 16.24126667389646
# --------------------------------------------------
# Validation Accuracy: 0.8866666666666667
# Non-zero kernels: 0.14615384615384616
# Linear sparsity: 0.9159891803675049
# Overall sparsity: 0.5772449566747901
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [61.51932621002197, 456.2187103271485, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 76
# --------------------------------------------------
# Train Accuracy: 0.9900350877192983
# Train Loss: 12.80469126580283
# --------------------------------------------------
# Validation Accuracy: 0.891
# Non-zero kernels: 0.14567307692307693
# Linear sparsity: 0.9164500725338491
# Overall sparsity: 0.5772914974275657
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [61.77190446853638, 457.9540939331055, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 77
# --------------------------------------------------
# Train Accuracy: 0.9905087719298246
# Train Loss: 11.887520748889074
# --------------------------------------------------
# Validation Accuracy: 0.895
# Non-zero kernels: 0.14615384615384616
# Linear sparsity: 0.9151656189555126
# Overall sparsity: 0.57678378012456
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [62.11511778831482, 459.7539337158203, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 78
# --------------------------------------------------
# Train Accuracy: 0.9883859649122807
# Train Loss: 14.162466107169166
# --------------------------------------------------
# Validation Accuracy: 0.8916666666666667
# Non-zero kernels: 0.14615384615384616
# Linear sparsity: 0.9152336194390716
# Overall sparsity: 0.5768218589222854
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [62.61114168167114, 461.63562164306643, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 79
# --------------------------------------------------
# Train Accuracy: 0.989859649122807
# Train Loss: 12.03597775939852
# --------------------------------------------------
# Validation Accuracy: 0.89
# Non-zero kernels: 0.14639423076923078
# Linear sparsity: 0.9150900628626693
# Overall sparsity: 0.5768472447874357
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [62.82600235939026, 462.96628875732426, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 80
# --------------------------------------------------
# Train Accuracy: 0.9917543859649123
# Train Loss: 10.477417687186971
# --------------------------------------------------
# Validation Accuracy: 0.8943333333333333
# Non-zero kernels: 0.1466346153846154
# Linear sparsity: 0.9152638418762089
# Overall sparsity: 0.577050331708638
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [63.116758823394775, 464.2638641357422, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 81
# --------------------------------------------------
# Train Accuracy: 0.988421052631579
# Train Loss: 14.186851405655034
# --------------------------------------------------
# Validation Accuracy: 0.8883333333333333
# Non-zero kernels: 0.14615384615384616
# Linear sparsity: 0.9152109526112185
# Overall sparsity: 0.5768091659897102
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [63.5374059677124, 466.4423706054688, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 82
# --------------------------------------------------
# Train Accuracy: 0.9890175438596491
# Train Loss: 13.626428087707609
# --------------------------------------------------
# Validation Accuracy: 0.8913333333333333
# Non-zero kernels: 0.1466346153846154
# Linear sparsity: 0.9158682906189555
# Overall sparsity: 0.5773888099106418
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [63.87667369842529, 467.99928283691406, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 83
# --------------------------------------------------
# Train Accuracy: 0.9920526315789474
# Train Loss: 9.991207938292064
# --------------------------------------------------
# Validation Accuracy: 0.8883333333333333
# Non-zero kernels: 0.1466346153846154
# Linear sparsity: 0.9160798476789168
# Overall sparsity: 0.5775072772813431
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [64.18140053749084, 469.3755035400391, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 84
# --------------------------------------------------
# Train Accuracy: 0.9920701754385965
# Train Loss: 9.903001070953906
# --------------------------------------------------
# Validation Accuracy: 0.8916666666666667
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9164122944874274
# Overall sparsity: 0.5773761169780666
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [64.45043659210205, 470.76063842773436, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 85
# --------------------------------------------------
# Train Accuracy: 0.9891228070175438
# Train Loss: 13.270307567552663
# --------------------------------------------------
# Validation Accuracy: 0.8886666666666667
# Non-zero kernels: 0.1466346153846154
# Linear sparsity: 0.9166767408123792
# Overall sparsity: 0.5778415245058218
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [64.8347659111023, 472.7211395263672, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 86
# --------------------------------------------------
# Train Accuracy: 0.9897543859649123
# Train Loss: 12.34139207098633
# --------------------------------------------------
# Validation Accuracy: 0.889
# Non-zero kernels: 0.14639423076923078
# Linear sparsity: 0.9169487427466151
# Overall sparsity: 0.5778880652585974
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [65.11759114265442, 474.3707977294922, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 87
# --------------------------------------------------
# Train Accuracy: 0.9925263157894737
# Train Loss: 9.400073654134758
# --------------------------------------------------
# Validation Accuracy: 0.8966666666666666
# Non-zero kernels: 0.14615384615384616
# Linear sparsity: 0.9172056334622823
# Overall sparsity: 0.5779261440563228
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [65.522944688797, 475.74952697753906, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 88
# --------------------------------------------------
# Train Accuracy: 0.9908070175438597
# Train Loss: 11.402821611380205
# --------------------------------------------------
# Validation Accuracy: 0.891
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9175380802707931
# Overall sparsity: 0.5780065326292987
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [65.83140802383423, 477.22624816894535, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 89
# --------------------------------------------------
# Train Accuracy: 0.9916491228070176
# Train Loss: 9.986785048036836
# --------------------------------------------------
# Validation Accuracy: 0.8926666666666667
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9175985251450677
# Overall sparsity: 0.578040380449499
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [66.10199928283691, 478.6444305419922, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 90
# --------------------------------------------------
# Train Accuracy: 0.9914035087719298
# Train Loss: 10.401192499266472
# --------------------------------------------------
# Validation Accuracy: 0.8866666666666667
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9172131890715667
# Overall sparsity: 0.5778246005957216
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [66.43811678886414, 479.9142333984375, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 91
# --------------------------------------------------
# Train Accuracy: 0.9868947368421053
# Train Loss: 16.12784211046528
# --------------------------------------------------
# Validation Accuracy: 0.8823333333333333
# Non-zero kernels: 0.1466346153846154
# Linear sparsity: 0.9178176378143134
# Overall sparsity: 0.5784804021121039
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [66.78040862083435, 482.03186798095703, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 92
# --------------------------------------------------
# Train Accuracy: 0.9906666666666667
# Train Loss: 12.180114918388426
# --------------------------------------------------
# Validation Accuracy: 0.893
# Non-zero kernels: 0.14615384615384616
# Linear sparsity: 0.9178251934235977
# Overall sparsity: 0.5782730842133766
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [67.02078771591187, 483.43605041503906, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 93
# --------------------------------------------------
# Train Accuracy: 0.9945964912280701
# Train Loss: 6.897859441611217
# --------------------------------------------------
# Validation Accuracy: 0.8923333333333333
# Non-zero kernels: 0.14615384615384616
# Linear sparsity: 0.9178780826885881
# Overall sparsity: 0.578302701056052
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [67.2269401550293, 484.2774856567383, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 94
# --------------------------------------------------
# Train Accuracy: 0.991578947368421
# Train Loss: 10.685993129416602
# --------------------------------------------------
# Validation Accuracy: 0.8856666666666667
# Non-zero kernels: 0.1466346153846154
# Linear sparsity: 0.917719414893617
# Overall sparsity: 0.5784253994042784
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [67.50217366218567, 485.59168853759763, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 95
# --------------------------------------------------
# Train Accuracy: 0.9905964912280701
# Train Loss: 12.046168244851287
# --------------------------------------------------
# Validation Accuracy: 0.8943333333333333
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.9182256407156673
# Overall sparsity: 0.578391551584078
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [67.963369846344, 487.26425781250003, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 96
# --------------------------------------------------
# Train Accuracy: 0.9922631578947368
# Train Loss: 9.245400995772798
# --------------------------------------------------
# Validation Accuracy: 0.8916666666666667
# Non-zero kernels: 0.1466346153846154
# Linear sparsity: 0.918331419245648
# Overall sparsity: 0.5787681085838072
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [68.12326145172119, 488.534912109375, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 97
# --------------------------------------------------
# Train Accuracy: 0.991719298245614
# Train Loss: 10.84921571938321
# --------------------------------------------------
# Validation Accuracy: 0.892
# Non-zero kernels: 0.14639423076923078
# Linear sparsity: 0.9183389748549323
# Overall sparsity: 0.578666565123206
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [68.27336573600769, 490.16028747558596, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 98
# --------------------------------------------------
# Train Accuracy: 0.9941228070175439
# Train Loss: 7.330393099808134
# --------------------------------------------------
# Validation Accuracy: 0.898
# Non-zero kernels: 0.1466346153846154
# Linear sparsity: 0.9183389748549323
# Overall sparsity: 0.5787723395613322
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [68.42614889144897, 491.04140777587895, 0.0]
# Learning rate: 0.001
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 99
# --------------------------------------------------
# Train Accuracy: 0.9913157894736843
# Train Loss: 11.162620619288646
# --------------------------------------------------
# Validation Accuracy: 0.8933333333333333
# Non-zero kernels: 0.14591346153846155
# Linear sparsity: 0.918716755319149
# Overall sparsity: 0.578666565123206
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [68.72405552864075, 492.6177032470703, 0.0]
# Learning rate: 0.0005

# %%
print(best_model.best_model)

torch.save(best_model.best_model.state_dict(), '../checkpoints/mnist_conv_sparse_adabreg.pth')

# %%
model = best_model.best_model
model.eval()

# %%
train.test(conf, model, test_loader)
